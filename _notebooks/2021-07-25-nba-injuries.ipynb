# %% [markdown]
# # "NBA Injury Report Sports Analytics Project (Part 1)"
# > "Introduction and setup for how to structure a complete sports analytics project"
#
# - toc: true
# - badges: true
# - comments: true
# - author Jeremy Abramson
# - categories: [sports analytics, nba, python, research, projects, injuries]
# - image: images/chart-preview.png

# %% [markdown]
# # Introduction

# %% [markdown]
# ## How To Read This Post

# %% [markdown]
# # Project Description
#
# It all started with a tweet from basketball analytics legend and Korean cinema aficionado [Ed Kupfer](https://twitter.com/EdKupfer):
# > twitter: https://twitter.com/EdKupfer/status/1385682808174256129
#
#
# Pretty straightforward, right?
#
# # Kickstarter Model™️ Goals
# As per The Kickstarter Model™️, we need to define our three goals.
# At first blush, we might suggest something like the following:
# - Fallback Goal: "Get the PDFs"
# - Baseline Goal: "Extract data from the PDFs"
# - Stretch Goal: "Present the data somehow"
#
# That's absolutely defensible, and has the bonus of structurally aligning with the major technical "tasks" of the project.
# But I'm not sure a directory full of PDFs qualifies as a "dataset" you could pass on to someone else as a contribution.
# Instead, we'll go with a slightly different approach (but feel free to use the above if it works better for you).

# %% [markdown]
# ## 1. Fallback Goal
# > Download and "lift" the data from the NBA Injury Report PDFs into some sort of machine-readable format (`CSV`, `JSON`, etc.)
#
# Since "getting the data" is kind of the main point of this entire exercise, even though extracting data from the PDFs requires requires some [at this point] unknown tooling, we're going to have both downloading *and* processing the PDFs be be our Fallback Goal.
# If we don't do anything else, or if nothing else "works", at least we'll have accomplished something useful that we can share with the community.

# %% [markdown]
# ## 2.  Baseline Goal
# > Present the data we obtained above in some sort of webapp/dashboard/etc.
#
# Structuring things this way now aligns with what we normally consider a "Baseline" Goal: A fully-fledged "deliverable" of some sort that provides value to the community.
# Doing this may sound a bit aggressive in terms of complexity, but our "webapp" doesn't need to be all that fancy.
# It's just a "skin" to slice and dice the data we generate from the Fallback Goal.
# It *should* be reasonably straightforward{% 10 fn %}.

# %% [markdown]
# ## 3.  Stretch Goal
# > None
#
# As we were pretty aggressive with our first two goals, I think it's perfectly reasonable to not have a Stretch Goal.
# Normally, you might think to say something vague like "analyze the injury data", but in my opinion, that's actually *counterproductive*.
# The reason being that the goal of this project isn't really analysis!
# The goal is is unlock some data in one format, and present it to "the user" in another format that's more amenable for *their* absorption.
# This may not sound very "sexy", but the reality is that this data collection/"chewing"/presenting process is basically [one of the most important things](https://www.sportperformanceanalysis.com/article/communication-with-coaches-as-a-performance-analyst) in sports analytics.
# So unless you have a *specific* analysis in mind, I think it makes sense to not have a Stretch Goal, and to just focus on the first two goals.
# If we do this right, perhaps something interesting will fall out of our dashboard, and we can explore it at that point.

# %% [markdown]
# > Note: Again, the point of setting these goals isn't to spur endless debate or to create another roadblock to starting a project.  It's just a way of structuring potential future design decisions, and making sure things like feature creep and "great-being-the-enemy-of-good" don't impede actually delivering on the goals.

# %% [markdown]
# Now that we have a conceptual goal framework in which to work, let's get to it!

# %% [markdown]
# # Fallback Goal: Downloading and Processing NBA Injury Report PDFs
#
# The Kickstarter Model™️ is there to help us structure our effort wisely, and make productive high level design decisions, but it doesn't really say anything about *how* to do whatever it is we want to do!
# To that end, once we have our goals, I find it's helpful to spend a little time — *before* coding! — structuring my thinking about each of the tasks at hand.

# %% [markdown]
# ## Divvying Up Tasks
# As per the discussion above, for our Fallback Goal, it seems like we already have two "high level" tasks:
#
# 1. Downloading PDFs
# 2. Processing PDFs.
#
# But we can break those down a little further.
# First off, we can't download anything without knowing *what* to download.
# Ed's tweet mentions "just change the date", it seems safe to assume we'll need to build a list of URLs based on dates, unless there's some central page with links to all of the injury reports, in which case we can just scrape the URLs from that.
#
# And, of course, at this point I'm not sure exactly how to extract the data from the PDFs (minor detail, right?!?)
# But I'm pretty confident it *can* be done, so we'll save a little "Google-fu" for later.
# However, it does seem reasonable to use `Pandas` to post-process our data once we do get it out of the PDF, since it's definitely going to be tabular.
# Lastly, we might want to fancy with [asynchronous requests](https://www.twilio.com/blog/asynchronous-http-requests-in-python-with-aiohttp) (or perhaps not!  It might not be worth the effort, but let's note it here).
#
# Taking all of the above into account, our **Fallback Goal** task outline might look like this:
#
# 1. Download PDFs
#     1. Generate list of URLs (dates) to injury report PDFs
#     2. Download URLs from list (do this asynchronously?)
# 2.  Process PDFs
#     1. Extract data from PDF (with what?)
#     2. Post-process data (Pandas)

# %% [markdown]
# > Tip: One thing we'll find as we progress is that this outline, as pedantic as it may seem, is incomplete.  Digging into the above steps, we'll invariably find places where the sub-steps aren't necessarily or obviously entailed by the macro steps.  If this gets too far out of hand — when, exactly, this happens is a bit of a judgment call — it makes sense to go back and revise the outline.  For the sake of this blog post, I'm going to go forward with this level of granularity, and we'll see how far we can get.

# %% [markdown]
# Now we can tackle these individually, and make sure we're always progressing toward the end goal!

# %% [markdown]
# ## Task 1: Downloading The Injury Reports
#
# Before we can actually do anything interesting with the injury reports, we need to download them.
# To do that, we need to know where there are.
# After some brief googling, it seems like there really isn't a central repository for these reports, and they're just uploaded one at a time{% fn 20 %}.
#
#
# The one example URL from Ed's tweet looks like this:
# > `https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-04-23_01PM.pdf`
#
#
# Looks like there's 4 parts to the URL:
# 1. Some boilerplate: `https://ak-static.cms.nba.com/referee/injury/Injury-Report_`
# 2. A date: `2021-04-23`
# 3. A time: `01PM`
# 4. The file extension: `.pdf`
#
# We're only interested in the middle two (the date and the time), as the boilerplate URL and the file extension won't change.  From googling{% fn 30 %} `"nba injury report"` and clicking on [the second link](https://official.nba.com/nba-injury-report-2020-21-season/) it seems like the times may be `1:30 PM`, `5:30 PM` and `8:30 PM`.
# Although from Ed's example, we see a `01PM` time in the URL, *not* `1:30`.
# So we'll go ahead and assume the appropriate times URL-wise are `01PM`, `05PM` and `08PM`.
# Lastly, for simplicity, let's just focus on the `8:30PM` (or `8PM`, in URL-speak) file, as it's likely to be the most complete.
# We can download the rest later if we want.

# %% [markdown]
# ### Generate a List of URLs to Download
# Google helped us sort out what we might use for the `time` portion of the URL, but the `date` part is actually a little more complicated than we might like, as we need to know the specific URL of each injury report we want to download.
# According to the [official NBA annoucement](https://official.nba.com/nba-injury-report-2020-21-season/), the dates we're interested in are actually the day *before* game days, except on the second days of back-to-backs, in which case presumably the injury report comes out the day of the game.
#
# This all sounds complicated, and if there's one thing I've learned about projects like this it's that nothing saps enthusiasm like complication and extra effort that doesn't "feel" like it's in the service of what we're trying to  accomplish{% fn 40 %}.
#
# So, given what we know, it seems as if we have two options:
# 1. Get a copy of the NBA schedule, and try to download reports for days we know there's a game
# 2. Just start downloading [a range of?] dates and see what we get
#
# There's nothing wrong with taking a stab at option 1 here, but this project is about injury reports, not the NBA schedule, so we'll start with option 2{% fn 50 %}.

# %% [markdown]
# #### Building a List of Dates: The Easy Way
# Programmatically dealing with dates can be [frustrating](https://xkcd.com/1179/), and doing so in Python is no exception.
# There's a whole rabbit hole we can go down, talking about `timedelta` objects and "date arithmetic" et cetera, but let's just cut right to the chase and use `Pandas`.
# Pandas certainly has its issues, but this is one case where it'll make our lives *much* simpler.
#
# So finally...some code!

# %%
import pandas as pd

# %% [markdown]
# (Okay, so that wasn't very satisfying.
# There's more code coming soon, I promise!)
#
# We're going to use the `pandas.date_range` ([docs](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html)) function to generate, well, a range of dates.
# We'll use these dates as portion of the URL schema detailed above, but in order to do so, we need to know what range to generate.
#
# The day before the start of the NBA season until the end of the NBA season seems like a reasonable starting point.
# If we needed to do this for some number of seasons, we'd want to automate this, but for now, let's just copy the dates manually.
# Perusing the [wikipedia page](https://en.wikipedia.org/wiki/2020–21_NBA_season) for the 2020-2021 NBA season, it looks like the season started on December 22, 2020, and [ended](https://www.youtube.com/watch?v=9O920AD-teU) on July 20th.
# From manual testing, [https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf](https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf) is a valid link, and the next day, unsurprisingly, is not.
#
# Remembering our "the injury reports can come out the day *before*" note from above, this gives us our range: `December 21, 2020` through `July 20, 2021`.

# %% [markdown]
# Looking at the [docs](https://pandas.pydata.org/docs/reference/api/pandas.date_range.html) for `pandas.date_range` it there's a ton of parameters we can use, but `start` and `end` look like they might be all we need.
# Now, for real this time, let's look at some code!

# %%
# This should generate some list-like thing of datetime-like things
season_dates = pd.date_range(start='12-21-2020', end='07-20-2021')
# Let's look at the first and last dates in our list
print(f'The 2020-21 NBA season started on {season_dates[0]}, and ended on {season_dates[-1]}')
# Out:
# The 2020-21 NBA season started on 2020-12-21 00:00:00, and ended on 2021-07-20 00:00:00

# %% [markdown]
# (It may not look like much, but if you have *any* idea how obnoxious this would be without `pandas`, you'll be impressed!)
# Now that we have our list of dates, we just need to add them to our URL schema.
# Let's define variables for the parts of the URL that are static (for now, we may want to download other `report_time` values later):
#
# As a reminder, the URL's look like this:
# > `https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf`

# %%
# We don't need to define a variable for the extension
url_stem = 'https://ak-static.cms.nba.com/referee/injury/Injury-Report_'
report_time = '08PM'

# %% [markdown]
# And let's build an example URL, using the first date from the `season_dates` list we created above:

# %%
print(f'{url_stem}{season_dates[0]}_{report_time}.pdf')
# Out:
# https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-21 00:00:00_08PM.pdf

# %% [markdown]
# Almost, but not quite!
# It looks like our `season_dates[0]` object is some sort of `datetime`-y type thing.
# Let's find out exactly:

# %%
print(f'{season_dates[0]} is of type {type(season_dates[0])}')
# Out:
# 2020-12-21 00:00:00 is of type <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# So, it's not quite a standard Python `datetime` object ([docs](https://docs.python.org/3/library/datetime.html#datetime.datetime)).
# But it sure seems like it might behave like one{% fn 60 %}.
# That being the case, let's just go ahead and try to use the standard method we use to process Python dates into strings: `strftime()`.

# %% [markdown]
# > Tip: I could never remember which one was which between `strftime` and `strptime` until I leared that `strftime()` is "string *from* time" and `strptime()` is "string *parse* time" ::"The More You Know" star whooshes by::

# %% [markdown]
# From our sample URL, it looks like we need things in a `YYYY-MM-DD` format.
# Luckily, that's a relatively simple format string, but if you want to try it out and be sure, [this interactive site for Python datetime format strings](https://www.strfti.me) is super cool.

# %%
from datetime import datetime

# %%
print(f"{url_stem}{datetime.strftime(season_dates[0], '%Y-%m-%d')}_{report_time}.pdf")
# Out:
# https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-21_08PM.pdf

# %% [markdown]
# > Note: Add note about `from` imports and changing to double-quotes in `f-strings`

# %% [markdown]
# Success!
#
# Now, let's build a list of similarly formatted URLs.

# %%
season_urls = list()
for day in season_dates:
    season_urls.append(f"{url_stem}{datetime.strftime(day, '%Y-%m-%d')}_{report_time}.pdf")

# %% [markdown]
# Or, if a list comprehension if you prefer (which seems reasonable here, since we're *building* a list):

# %%
season_urls = [f"{url_stem}{datetime.strftime(day, '%Y-%m-%d')}_{report_time}.pdf" for day in season_dates]

# %% [markdown]
# Let's sanity check the first five URLs:

# %%
season_urls[:5]
# Out:
# ['https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-21_08PM.pdf',
#  'https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-22_08PM.pdf',
#  'https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-23_08PM.pdf',
#  'https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-24_08PM.pdf',
#  'https://ak-static.cms.nba.com/referee/injury/Injury-Report_2020-12-25_08PM.pdf']

# %% [markdown]
# Looks like we're good to go!

# %% [markdown]
# ### Download the PDFs

# %% [markdown]
# For simplicity's sake, we'll just use the `requests` module to download the PDFs sequentially.
# Later, we can see about using *asynchronous* requests to greatly speed up our downloads, but for now let's just do things one at a time.
#
# We could do this lazily, with something simple like:
# ```python
# import requests
# # Loop through our URL list
# for url in season_urls:
#     # Download the PDF
#     resp = requests.get(url)
#     # Write to disk; Create a filename from the URL
#     filename = url.split('/')[-1]
#     with open(filename, 'wb') as f:
#         f.write(resp.content)
# ```
#
# With the code above, what happens if there's no report for a specific day?
# Or if there's a network error, either with the server or our own internet?
#
# In general, it's a good idea to program a little defensively when accessing network assets, especially in cases like this, where there's a high likelihood of accessing an "invalid" URL (i.e. one with nothing on the other end to download).
# It's easy to imagine the downstream PDF processing — that we haven't written yet 🙂 — breaking when it tries to open an empty file, for example.
# We could try to handle the error at that point, but it's probably better to do it here, and only write valid files{% fn 70 %}.
#
# We'll assume that accessing a URL with a valid injury report on the other end will return [HTTP status code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) **200** ("Success!"), and one without a PDF will return something else{% fn 80 %}.
# To handle this, we'll use the `requests` library's `raise_for_status()` method, which can raise an exception when we get a non-success status code.
# We can then catch that exception, and skip writing the file.
#
# Let's add that to the code above:

# %% [markdown]
# > Tip: You'll see some code that explicitly *tests* for a specific `status code` code using an `if` statement, but this is almost always a job for a `try/except` block.  One of the core "Pythonic" tenets is "Ask for forgiveness, not permission".

# %% [markdown]
# ```python
# import requests
#
# # Loop through our URL lists
# for url in season_urls:
#     resp = requests.get(url)
#     try:
#         resp.raise_for_status()
#     # This is the exception to catch for non-200 response codes; this won't necessarily catch network errors
#     except requests.HTTPError:
#         print(f'No valid PDF at {url}, removing from list')
#         season_dates.remove(url)
#     # The "else" block of a try/except happens if there isn't an exception
#     else:
#         filename = url.split('/')[-1]
#         # Write to disk
#         print(f'Writing PDF for {url}')
#         with open(filename, 'wb') as f:
#             f.write(resp.content)
# ```

# %% [markdown]
# > Important: Note that the `.raise_for_status()` call is the one that raises the exception, **not** the `.get()` call!  Make sure `raise_for_status()` is inside your `try/except` block!

# %% [markdown]
# One thing we might note is that if we want to download the other injury report times, we'll need to create a new list of URLs.
# That being the case, perhaps it might make sense to construct the URL right before we use it, instead of all at once before hand.
# And while we're at it, perhaps we should make this a function, so we don't have to download all the files in a loop if we don't want to.
#
# The function should take two parameters, the `date` to download, and the `time` of the report (unsurprisingly, these are the two "dynamic" parts of our URL schema.)
# We can use the chunks of code from building our URL list above to construct the URL right before we use it.

# %%
import requests
def download_injury_report(report_date, report_time='08PM'):
    # So we can alert an interactive user if something goes wrong
    from warnings import warn
    url_stem = 'https://ak-static.cms.nba.com/referee/injury/Injury-Report_'
    
    # Build the URL
    url = f"{url_stem}{datetime.strftime(report_date, '%Y-%m-%d')}_{report_time}.pdf"
    # Fetch the PDF
    resp = requests.get(url)
    try:
        resp.raise_for_status()
    # This is the exception to catch for non-200 response codes; this won't necessarily catch network errors
    except requests.HTTPError:
        # Just beccause the caller will have to make sure to handle the "None" case doesn't mean we can't alert them
        # stacklevel=2 cribbed from: https://stackoverflow.com/questions/60083173/warnings-module-prints-part-of-warning-twice
        warn(f'Could not download URL {url}', stacklevel=2)
        return None
    # The "else" block of a try/except happens if there isn't an exception
    else:
        # Return the content to the caller; they can write it to disk or process it
        return resp

# %% [markdown]
# > Note: You may be surprised that I removed the part that writes the PDF to disk.  I'll spare you the bloviating, but in general I try to adopt a somewhat "[functional](https://betterprogramming.pub/what-is-a-pure-function-3b4af9352f6f)" programming style whenever possible.  Basically, this means I try not to have lots of things happening inside my functions that someone using them might not be aware of (in this context, these things are called "side effects").  A function called `download_injury_report` should basically just do that (and nothing else).  If we want to save the report we can do that too, but we should be explicit about where and how that is happening.  By returning the response object, we can let the caller — us, but us outside this function! — decide what to do with it.

# %% [markdown]
# Let's give our function a shot!
# We'll use one of the dates we generated previously (note that we don't have to provide a time, since we put a default value for the function above).

# %%
season_dates[-3]
# Out:
# Timestamp('2021-07-18 00:00:00', freq='D')

# %%
resp = download_injury_report(season_dates[-3])
# Out:
# <ipython-input-24-22c96f8a63d8>:1: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-18_08PM.pdf
#   resp = download_injury_report(season_dates[-3])

# %% [markdown]
# Okay, I cheated a bit, and chose a date with no game.
# But it looks like our warning is working correctly!
# Let's download a valid PDF and write it to disk:

# %%
resp = download_injury_report(season_dates[0])

# Never can be too careful!
if resp:
    # Rather than convert season_dates[0] to a string, let's just use the .url attribute
    # from the requests.response object, and process the filename like we did above
    filename = resp.url.split('/')[-1]
    with open(filename, 'wb') as f:
        f.write(resp.content)
        print(f'Wrote {filename} succesfully')
# Out:
# Wrote Injury-Report_2020-12-21_08PM.pdf succesfully

# %% [markdown]
# If you've cloned this notebook and are running it, you should have a copy of `Injury-Report_2020-12-21_08PM.pdf` in the `_notebooks` directory of the repo.
#
# Now let's download the season's worth, but putting something like the above back in a loop.
# We'll make two small modifications though, using two of the best and most indispensable libraries in the modern Python ecosystem.
# First, we'll define a `data` directory to write our files (using the sublime `pathlib`), so we don't clutter our `_notebooks` directory, and secondly, we'll use the *amazing* [tqdm](https://github.com/tqdm/tqdm) to monitor our progress, instead of printing a status message{% fn 90 %}.

# %% [markdown]
# > Tip: If you don't have `tqdm` installed (for shame!), `conda install -c conda-forge tqdm` (or `pip install tqdm` if you *must*) will do the trick.  You *are* using a Conda environment for this, right?!?

# %%
from tqdm.notebook import tqdm
from pathlib import Path

# Check out https://stackoverflow.com/questions/50110800/python-pathlib-make-directories-if-they-don-t-exist
# for more on the .mkdir() method
DATA_DIR = Path.cwd() /'injury_reports'
DATA_DIR.mkdir(parents=True, exist_ok=True)

for day in tqdm(season_dates):
    resp = download_injury_report(day)

    # Never can be too careful!
    if resp:
        # Rather than convert season_dates[0] to a string, let's just use the .url attribute
        # from the requests.response object, and process the filename like we did above
        filename = resp.url.split('/')[-1]
        with open(DATA_DIR / filename, 'wb') as f:
            f.write(resp.content)
# Out:
#   0%|          | 0/212 [00:00<?, ?it/s]
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-03-05_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-03-08_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-04_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-09_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-12_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-15_08PM.pdf
#   resp = download_injury_report(day)
# <ipython-input-95-ce591fe8e6d1>:10: UserWarning: Could not download URL https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-18_08PM.pdf
#   resp = download_injury_report(day)

# %% [markdown]
# ## Task 2: Extracting Tables from PDF Files
#
# Now that we have our 205 injury report PDFs (culled from 212 days!), it's time to extract the data in the tables.
# While I've briefly played around with optical character recognition (OCR) tools like [Tesseract](https://github.com/tesseract-ocr/tesseract), strict OCR seemed like a bad fit.
# Other than that, I wasn't sure what tool to use, which means...google to the rescue!
#
# At first, I [foolishly] googled for "*python parse PDF*", and eventually "*python parse PDF text*", thinking  it'd be obvious I meant "parse PDF **tables**".
# Apparently clairvoyance isn't quite built into google [yet], so I ended up checking out packages such as [PyPDF2](https://pypi.org/project/PyPDF2/), [pdfreader](https://pypi.org/project/pdfreader/), and eventually [pdfminer.six](pdfminer.six).
# These tools seem much more oriented toward programmatically creating and manipulating PDF documents, than extracting text.
# Eventually down the list of google results I came upon [this stackoverflow post](https://stackoverflow.com/questions/34837707/how-to-extract-text-from-a-pdf-file).
# One of the answers mentioned [tabula](https://tabula.technology) and converting PDF tables to dataframes.
# This seemed promising,

# %%
import tabula
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)

# %%
injury_reports = sorted(list(DATA_DIR.glob('*.pdf')))

# %%
injury_reports[0]
# Out:
# PosixPath('/Users/abramson/git/jeremyabramson/blog/_notebooks/injury_reports/Injury-Report_2020-12-21_08PM.pdf')

# %%
tabula.read_pdf(DATA_DIR / injury_reports[0], pages='all')
# Out:
#     Game Date   Game Time                Matchup                Team  \
# 0  12/22/2020  07:00 (ET)                GSW@BKN       Brooklyn Nets
# 1         NaN         NaN  Golden State Warriors     Green, Draymond
# 2         NaN         NaN                    NaN     Smailagic, Alen
# 3  10:00 (ET)     LAC@LAL            LA Clippers  Morris Sr., Marcus
#
#         Player Name                         Current Status  \
# 0  Claxton, Nicolas                                    Out
# 1               Out  Injury/Illness - Right foot; soreness
# 2               Out  Injury/Illness - Right Knee; Soreness
# 3               Out  Injury/Illness - Right Knee; Soreness
#
#                                       Reason
# 0  Injury/Illness - Right Knee; Tendinopathy
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN

# %%
tabula.read_pdf(DATA_DIR / injury_reports[-1], pages='all')
# Out:
#       Game Date          Game Time  Matchup  \
# 0    07/20/2021         09:00 (ET)  PHX@MIL
# 1           NaN  DiVincenzo, Donte      Out
# 2  Phoenix Suns       Saric, Dario      Out
#
#                                    Team              Player Name  \
# 0                       Milwaukee Bucks  Antetokounmpo, Thanasis
# 1  Injury/Illness - Left Ankle; Surgery                      NaN
# 2      Injury/Illness - Right Acl; Tear                      NaN
#
#   Current Status                       Reason
# 0            Out  Health and Safety Protocols
# 1            NaN                          NaN
# 2            NaN                          NaN

# %%
tabula.read_pdf(DATA_DIR / injury_reports[100], pages='all')
# Out:
#                   Game Date              Game Time                 Matchup  \
# 0                04/02/2021             07:00 (ET)                 GSW@TOR
# 1                       NaN                    NaN                     NaN
# 2                       NaN                    NaN                     NaN
# 3                       NaN                    NaN                     NaN
# 4                       NaN                    NaN         Toronto Raptors
# 5                       NaN                    NaN                     NaN
# 6                       NaN                    NaN                     NaN
# 7                       NaN                    NaN                     NaN
# 8                       NaN                    NaN                     NaN
# 9                07:30 (ET)                DAL@NYK        Dallas Mavericks
# 10                      NaN                    NaN                     NaN
# 11                      NaN                    NaN                     NaN
# 12                      NaN                    NaN         New York Knicks
# 13                      NaN                    NaN                     NaN
# 14                      NaN                    NaN                     NaN
# 15                      NaN                    NaN                     NaN
# 16                      NaN                HOU@BOS          Boston Celtics
# 17                      NaN                    NaN                     NaN
# 18                      NaN                    NaN                     NaN
# 19                      NaN                    NaN         Houston Rockets
# 20                      NaN                    NaN                     NaN
# 21                      NaN                    NaN                     NaN
# 22                      NaN                    NaN                     NaN
# 23               08:00 (ET)                CHA@IND       Charlotte Hornets
# 24                      NaN            Monk, Malik                     Out
# 25           Indiana Pacers       Brogdon, Malcolm                     Out
# 26                Game Date              Game Time                 Matchup
# 27                      NaN                    NaN                     NaN
# 28                      NaN                    NaN                     NaN
# 29                      NaN                    NaN                     NaN
# 30                      NaN                MIN@MEM       Memphis Grizzlies
# 31                      NaN                    NaN                     NaN
# 32                      NaN                    NaN                     NaN
# 33                      NaN                    NaN  Minnesota Timberwolves
# 34                      NaN                    NaN                     NaN
# 35                      NaN                    NaN                     NaN
# 36               09:00 (ET)                ATL@NOP           Atlanta Hawks
# 37                      NaN                    NaN                     NaN
# 38                      NaN                    NaN                     NaN
# 39                      NaN                    NaN                     NaN
# 40                      NaN                    NaN                     NaN
# 41                      NaN                    NaN                     NaN
# 42                      NaN                    NaN    New Orleans Pelicans
# 43                      NaN                    NaN                     NaN
# 44                      NaN                    NaN                     NaN
# 45                      NaN                    NaN                     NaN
# 46                      NaN                    NaN                     NaN
# 47                      NaN                CHI@UTA           Chicago Bulls
# 48                      NaN                    NaN                     NaN
# 49                      NaN                    NaN                     NaN
# 50                      NaN                    NaN               Utah Jazz
# 51                      NaN                    NaN                     NaN
# 52                      NaN                    NaN                     NaN
# 53               10:00 (ET)                LAL@SAC      Los Angeles Lakers
# 54                Game Date              Game Time                 Matchup
# 55                      NaN                    NaN                     NaN
# 56                      NaN                    NaN                     NaN
# 57                      NaN                    NaN                     NaN
# 58                      NaN                    NaN                     NaN
# 59                      NaN                    NaN                     NaN
# 60                      NaN                    NaN                     NaN
# 61                      NaN                    NaN                 MIL@POR
# 62                      NaN                    NaN                     NaN
# 63                      NaN                    NaN                     NaN
# 64                      NaN                    NaN                     NaN
# 65                      NaN                    NaN                     NaN
# 66                      NaN                    NaN                 OKC@PHX
# 67                      NaN                    NaN                     NaN
# 68                      NaN                    NaN                     NaN
# 69                      NaN                    NaN                     NaN
# 70                      NaN                    NaN                     NaN
# 71                      NaN                    NaN                     NaN
# 72                      NaN                    NaN                     NaN
# 73                      NaN                    NaN                     NaN
# 74               04/03/2021             07:00 (ET)                 DAL@WAS
# 75                      NaN                    NaN      Washington Wizards
# 76                      NaN                    NaN                     NaN
# 77                      NaN                    NaN                     NaN
# 78               08:00 (ET)                CLE@MIA     Cleveland Cavaliers
# 79                      NaN       Nance Jr., Larry                     Out
# 80                      NaN         Windler, Dylan                     Out
# 81               Miami Heat             Okpala, KZ                     Out
# 82                Game Date              Game Time                 Matchup
# 83                      NaN                    NaN                     NaN
# 84                      NaN                MIN@PHI  Minnesota Timberwolves
# 85                      NaN                    NaN      Philadelphia 76ers
# 86                      NaN                    NaN                     NaN
# 87                      NaN                NYK@DET         Detroit Pistons
# 88                      NaN                    NaN                     NaN
# 89                      NaN                    NaN         New York Knicks
# 90               09:00 (ET)                IND@SAS          Indiana Pacers
# 91                      NaN                    NaN       San Antonio Spurs
# 92                      NaN                    NaN                     NaN
# 93                      NaN                    NaN                     NaN
# 94                      NaN                    NaN                     NaN
# 95                      NaN                ORL@UTA           Orlando Magic
# 96                      NaN                    NaN                     NaN
# 97                      NaN                    NaN                     NaN
# 98                      NaN                    NaN                     NaN
# 99                      NaN                    NaN                     NaN
# 100                     NaN                    NaN                     NaN
# 101                     NaN                    NaN                     NaN
# 102                     NaN                    NaN                     NaN
# 103                     NaN                    NaN               Utah Jazz
# 104              10:00 (ET)                MIL@SAC         Milwaukee Bucks
# 105                     NaN       Sacramento Kings                     NaN
# 106                 OKC@POR  Oklahoma City Thunder                     NaN
# 107  Portland Trail Blazers                    NaN                     NaN
#
#                                      Team               Player Name  \
# 0                   Golden State Warriors            Curry, Stephen
# 1                         Green, Draymond                 Available
# 2                           Poole, Jordan                 Available
# 3                          Thompson, Klay                       Out
# 4                           Harris, Jalen                       Out
# 5                            Hood, Rodney                       Out
# 6                             Lowry, Kyle                       Out
# 7                          McCaw, Patrick                       Out
# 8                            Watson, Paul                       Out
# 9                    Cauley-Stein, Willie                       Out
# 10                             Redick, JJ                       Out
# 11                          Terry, Tyrell                       Out
# 12                            Barrett, RJ                 Available
# 13                        Bullock, Reggie                 Available
# 14                     Robinson, Mitchell                       Out
# 15                          Rose, Derrick                 Available
# 16                        Langford, Romeo                       Out
# 17                          Ojeleye, Semi                       Out
# 18                      Thompson, Tristan                       Out
# 19                            Exum, Dante                       Out
# 20                           Gordon, Eric                       Out
# 21                           Nwaba, David                       Out
# 22                             Wall, John                       Out
# 23                           Ball, LaMelo                       Out
# 24   Injury/Illness - Right Ankle; Sprain                       NaN
# 25       Injury/Illness - Right Hip; Sore                       NaN
# 26                                   Team               Player Name
# 27                                    NaN              Lamb, Jeremy
# 28                      Sabonis, Domantas                 Available
# 29                           Warren, T.J.                       Out
# 30                         Allen, Grayson                 Available
# 31                     Jackson Jr., Jaren                       Out
# 32                       Winslow, Justise                       Out
# 33                           Okogie, Josh                 Available
# 34                           Rubio, Ricky                       Out
# 35                      Russell, D'Angelo                       Out
# 36                          Collins, John                       Out
# 37                             Dunn, Kris                       Out
# 38                      Gallinari, Danilo                       Out
# 39                       Hunter, De'Andre                       Out
# 40                           Reddish, Cam                       Out
# 41                            Young, Trae                       Out
# 42                          Adams, Steven                       Out
# 43                            Ball, Lonzo                       Out
# 44                             Hart, Josh                       Out
# 45                        Ingram, Brandon                       Out
# 46                       Williamson, Zion                       Out
# 47                           LaVine, Zach                 Available
# 48                        Temple, Garrett                       Out
# 49                            White, Coby                 Available
# 50                        Azubuike, Udoka                       Out
# 51                            Ingles, Joe                 Available
# 52                          Morgan, Juwan                       Out
# 53                         Davis, Anthony                       Out
# 54                                   Team               Player Name
# 55                                    NaN           Drummond, Andre
# 56                          Dudley, Jared                       Out
# 57                          James, LeBron                       Out
# 58                                    NaN          Matthews, Wesley
# 59                       Sacramento Kings        Bagley III, Marvin
# 60                                    NaN         Whiteside, Hassan
# 61                        Milwaukee Bucks             Portis, Bobby
# 62                                    NaN              Teague, Jeff
# 63                                    NaN              Tucker, P.J.
# 64                 Portland Trail Blazers             Collins, Zach
# 65                                    NaN            Little, Nassir
# 66                  Oklahoma City Thunder            Bazley, Darius
# 67                                    NaN            Dort, Luguentz
# 68                                    NaN  Gilgeous-Alexander, Shai
# 69                                    NaN                Jerome, Ty
# 70                                    NaN             Muscala, Mike
# 71                           Phoenix Suns             Craig, Torrey
# 72                                    NaN           Kaminsky, Frank
# 73                                    NaN              Nader, Abdel
# 74                       Dallas Mavericks                       NaN
# 75                          Beal, Bradley              Questionable
# 76                         Bryant, Thomas                       Out
# 77                        Gafford, Daniel                       Out
# 78                         Allen, Jarrett                       Out
# 79      Injury/Illness - Illness; Illness                       NaN
# 80   Injury/Illness - Left Knee; Soreness                       NaN
# 81            Health and Safety Protocols                       NaN
# 82                                   Team               Player Name
# 83                                    NaN             Vincent, Gabe
# 84                                    NaN                       NaN
# 85                           Embiid, Joel              Questionable
# 86                           Hill, George                       Out
# 87                       McGruder, Rodney                       Out
# 88                         Okafor, Jahlil                       Out
# 89                                    NaN                       NaN
# 90                                    NaN                       NaN
# 91                      Bates-Diop, Keita                       Out
# 92                          Dieng, Gorgui                       Out
# 93                            Lyles, Trey                       Out
# 94                      Walker IV, Lonnie                       Out
# 95                          Anthony, Cole                       Out
# 96                            Birch, Khem              Questionable
# 97               Carter-Williams, Michael              Questionable
# 98                        Fultz, Markelle                       Out
# 99                           Harris, Gary                       Out
# 100                       Isaac, Jonathan                       Out
# 101                           Mane, Karim              Questionable
# 102                        Ross, Terrence              Questionable
# 103                                   NaN                       NaN
# 104                                   NaN                       NaN
# 105                                   NaN         NOT YET SUBMITTED
# 106                                   NaN         NOT YET SUBMITTED
# 107                     NOT YET SUBMITTED                       NaN
#
#                                         Current Status  \
# 0                                                  Out
# 1                 Injury/Illness - Left Finger; Sprain
# 2                  Injury/Illness - Left Ankle; Sprain
# 3       Injury/Illness - Right Achilles Tendon; Repair
# 4                  Injury/Illness - Right Hip; Pointer
# 5           Injury/Illness - Right Hip; Flexor; strain
# 6               Injury/Illness - Right Foot; Infection
# 7                 Injury/Illness - Left Knee; Swelling
# 8                          Health and Safety Protocols
# 9                          Health and Safety Protocols
# 10               Injury/Illness - Right Heel; Soreness
# 11                                    Personal Reasons
# 12              Injury/Illness - Right Ankle; sprained
# 13                   Injury/Illness - Illness; illness
# 14                Injury/Illness - Right Foot; surgery
# 15                   Injury/Illness - Left Ankle; sore
# 16   Injury/Illness - Illness; Post Health & Safety...
# 17                  Injury/Illness - Left Side; Strain
# 18                         Health and Safety Protocols
# 19                 Injury/Illness - Right Calf; Strain
# 20                Injury/Illness - Right Groin; Strain
# 21                Injury/Illness - Right Wrist; Sprain
# 22                Injury/Illness - Left Knee; Effusion
# 23              Injury/Illness - Right Wrist; Fracture
# 24                                                 NaN
# 25                                                 NaN
# 26                                      Current Status
# 27                                                 Out
# 28               Injury/Illness - Left Quad; Contusion
# 29         Injury/Illness - Left Foot; Stress Fracture
# 30                 Injury/Illness - Left Hip; Soreness
# 31   Injury/Illness - Left Knee; Meniscus Surgery R...
# 32              Injury/Illness - Right Thigh; Soreness
# 33                         Health and Safety Protocols
# 34                       Injury/Illness - Back; Spasms
# 35                 Injury/Illness - Left Knee; Surgery
# 36                 Injury/Illness - Left Ankle; Sprain
# 37               Injury/Illness - Right Ankle; Surgery
# 38            Injury/Illness - Left Achilles; Soreness
# 39               Injury/Illness - Right Knee; Soreness
# 40           Injury/Illness - Right Achilles; Soreness
# 41                Injury/Illness - Left Knee; Soreness
# 42              Injury/Illness - Right Ankle; Soreness
# 43           Injury/Illness - Right Hip Flexor; Strain
# 44                Injury/Illness - Right Thumb; Sprain
# 45        Injury/Illness - Right First MTP; Irritation
# 46                Injury/Illness - Right Thumb; Sprain
# 47                                                   -
# 48            Injury/Illness - Right Hamstring; Strain
# 49                                                   -
# 50         Injury/Illness - Right Ankle; Severe Sprain
# 51           Injury/Illness - Left Lower Leg; Soreness
# 52               Injury/Illness - Left Calf; Tightness
# 53                 Injury/Illness - Right Calf; strain
# 54                                      Current Status
# 55                                                 Out
# 56                    Injury/Illness - Right MCL; Tear
# 57                Injury/Illness - Right Ankle; sprain
# 58                                        Questionable
# 59                                                 Out
# 60                                        Questionable
# 61                                        Questionable
# 62                                        Questionable
# 63                                                 Out
# 64                                                 Out
# 65                                                 Out
# 66                                                 Out
# 67                                                 Out
# 68                                                 Out
# 69                                        Questionable
# 70                                                 Out
# 71                                        Questionable
# 72                                                 Out
# 73                                                 Out
# 74                                                 NaN
# 75     Injury/Illness - Right Hip; Right hip contusion
# 76         Injury/Illness - Left Knee; Left ACL injury
# 77    Injury/Illness - Right Ankle; Right ankle sprain
# 78                   Injury/Illness - Head; Concussion
# 79                                                 NaN
# 80                                                 NaN
# 81                                                 NaN
# 82                                      Current Status
# 83                                            Probable
# 84                                   NOT YET SUBMITTED
# 85             Injury/Illness - Left Knee; Bone bruise
# 86               Injury/Illness - Right Thumb; Surgery
# 87                Injury/Illness - Right Elbow; Sprain
# 88                 Injury/Illness - Left Knee; Surgery
# 89                                   NOT YET SUBMITTED
# 90                                   NOT YET SUBMITTED
# 91            Injury/Illness - Right Hamstring; Strain
# 92             Injury/Illness - Right Shoulder; Sprain
# 93                Injury/Illness - Right Ankle; Sprain
# 94              Injury/Illness - Right Wrist; Soreness
# 95   Injury/Illness - Right Rib; Non-displaced frac...
# 96           Injury/Illness - N/a; Illness (non-Covid)
# 97           Injury/Illness - N/a; Illness (non-Covid)
# 98                Injury/Illness - Left Knee; Torn ACL
# 99              Injury/Illness - Left Adductor; Strain
# 100        Injury/Illness - Left Knee; Injury recovery
# 101             Injury/Illness - Right Hamstring; Sore
# 102             Injury/Illness - Right Ankle; Sprained
# 103                                  NOT YET SUBMITTED
# 104                                  NOT YET SUBMITTED
# 105                                                NaN
# 106                                                NaN
# 107                                                NaN
#
#                                              Reason
# 0              Injury/Illness - Tailbone; Contusion
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                              NaN
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                           Reason
# 27               Injury/Illness - Right Toe; Sprain
# 28                                              NaN
# 29                                              NaN
# 30                                              NaN
# 31                                              NaN
# 32                                              NaN
# 33                                              NaN
# 34                                              NaN
# 35                                              NaN
# 36                                              NaN
# 37                                              NaN
# 38                                              NaN
# 39                                              NaN
# 40                                              NaN
# 41                                              NaN
# 42                                              NaN
# 43                                              NaN
# 44                                              NaN
# 45                                              NaN
# 46                                              NaN
# 47                                              NaN
# 48                                              NaN
# 49                                              NaN
# 50                                              NaN
# 51                                              NaN
# 52                                              NaN
# 53                                              NaN
# 54                                           Reason
# 55        Injury/Illness - Right Big Toe; contusion
# 56                                              NaN
# 57                                              NaN
# 58                 Injury/Illness - Neck; contusion
# 59   Injury/Illness - Left 4th Metacarpal; Fracture
# 60            Injury/Illness - Right Knee; Soreness
# 61                      Health and Safety Protocols
# 62                      Health and Safety Protocols
# 63               Injury/Illness - Left Calf; Strain
# 64     Injury/Illness - Left Ankle; Stress Fracture
# 65             Injury/Illness - Right Thumb; Sprain
# 66        Injury/Illness - Left Shoulder; Contusion
# 67        Injury/Illness - N/a; Concussion Protocol
# 68   Injury/Illness - Right Foot; Plantar Fasciitis
# 69             Injury/Illness - Right Ankle; Sprain
# 70             Injury/Illness - Right Ankle; Sprain
# 71             Injury/Illness - Left Knee; Soreness
# 72                      Health and Safety Protocols
# 73            Injury/Illness - Right Knee; Soreness
# 74                                NOT YET SUBMITTED
# 75                                              NaN
# 76                                              NaN
# 77                                              NaN
# 78                                              NaN
# 79                                              NaN
# 80                                              NaN
# 81                                              NaN
# 82                                           Reason
# 83            Injury/Illness - Right Knee; Soreness
# 84                                              NaN
# 85                                              NaN
# 86                                              NaN
# 87                                              NaN
# 88                                              NaN
# 89                                              NaN
# 90                                              NaN
# 91                                              NaN
# 92                                              NaN
# 93                                              NaN
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
# 98                                              NaN
# 99                                              NaN
# 100                                             NaN
# 101                                             NaN
# 102                                             NaN
# 103                                             NaN
# 104                                             NaN
# 105                                             NaN
# 106                                             NaN
# 107                                             NaN

# %%
df = tabula.read_pdf(injury_reports[40], stream=True, pages='all')

# %%
df = df.drop(df.loc[df['Game Date'] == 'Game Date'].index).reset_index(drop=True)
df['Game Date'] = df['Game Date'].fillna(method='pad')
df['Matchup'] = df['Matchup'].fillna(method='pad')
df['Team'] = df['Team'].fillna(method='pad')
df['Game Time'] = df['Game Time'].fillna(method='pad')
#df[['Last Name', 'First Name']] = df['Player Name'].str.split(',', expand=True)
#df = df.drop(columns=['Player Name'])

# %%
df
# Out:
#      Game Date   Game Time  Matchup                    Team Current Status  \
# 0   01/30/2021  08:00 (ET)  HOU@NOP         Houston Rockets            Out
# 1   01/30/2021  08:00 (ET)  HOU@NOP         Houston Rockets            Out
# 2   01/30/2021  08:00 (ET)  HOU@NOP         Houston Rockets            Out
# 3   01/30/2021  08:00 (ET)  HOU@NOP         Houston Rockets            Out
# 4   01/30/2021  08:00 (ET)  HOU@NOP    New Orleans Pelicans            Out
# 5   01/30/2021  08:00 (ET)  MIL@CHA       Charlotte Hornets            Out
# 6   01/30/2021  08:00 (ET)  MIL@CHA       Charlotte Hornets            Out
# 7   01/30/2021  08:00 (ET)  MIL@CHA       Charlotte Hornets            Out
# 1          Kenyon
# 2           Kevin
# 3         Brodric
# 4            Naji
# 5          Vernon
# 6            Nate
# 7           Jalen
# 8           Grant
# 9         Wendell
# 10          Devon
# 11           Zach
# 12         Robert
# 13        Derrick
# 14             CJ
# 15          Jusuf
# 16          Avery
# 17          Jimmy
# 18          Goran
# 19        Maurice
# 20         Udonis
# 21          Tyler
# 22          Andre
# 23         Meyers
# 24          Chris
# 25           Gabe
# 26        Nemanja
# 27         DaQuan
# 28       Jahmi'us
# 29         Robert
# 30          Romeo
# 31         Payton
# 32         Kostas
# 33        Anthony
# 34          Jared
# 35         LeBron
# 36        Grayson
# 37          Jaren
# 38           Sean
# 39         Jontay
# 40        Killian
# 41          Jonas
# 42        Justise
# 43           Luka
# 44           Maxi
# 45       Kristaps
# 46        Ty-Shon
# 47          Devin
# 48         Damian
# 49        Cameron
# 50          Dario
# 51        Killian
# 52       Marquese
# 53           Alen
# 54           Klay
# 55        Patrick
# 56         Reggie
# 57             PJ
# 58          Jamal
# 59           Greg
# 60        Derrick
# 61          Trent
# 62         Elijah
# 63        Donovan
# 64        Nicolas
# 65        Spencer
# 66          James
# 67         Thomas
# 68           Raul
# 69      Al-Farouq
# 70        Michael
# 71       Markelle
# 72       Jonathan
# 73          Karim
# 74          Chuma
# 75             OG
# 76          Jalen
# 77        Patrick
# 78         Norman
# 79          Brian
# 80          Jalen
# 81          Caris
# 82           Doug
# 83        Cassius
# 84           T.J.
# 85           Joel
# 86       Terrance
# 87           Paul
# 88           Mike
# 89         Rayjon
# 90        Marques
# 91        Matthew
# 92          Kevin
# 93          Lamar
# 94        Jarrett
# 95         Ashton
# 96        Juancho
# 97            Naz
# 98       D'Angelo
# 99   Karl-Anthony

# %%
def clean_injury_report(df):
    df = df.drop(df.loc[df['Game Date'] == 'Game Date'].index).reset_index(drop=True)
    df['Game Date'] = df['Game Date'].fillna(method='pad')
    df['Matchup'] = df['Matchup'].fillna(method='pad')
    df['Team'] = df['Team'].fillna(method='pad')
    df['Game Time'] = df['Game Time'].fillna(method='pad')
    return df

# %%
from pathlib import Path
from tqdm.notebook import tqdm

# %%
pdfs = sorted(list(Path('./injury_reports').glob('*.pdf')))

# %%
tabula.read_pdf('2021-05-20_08PM.pdf', stream=True, guess=False, pages='all')
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2             Unnamed: 3  \
# 0    Game Date   Game Time    Matchup                   Team
# 1   05/20/2021  08:00 (ET)    IND@WAS         Indiana Pacers
# 2          NaN         NaN        NaN                    NaN
# 3          NaN         NaN        NaN                    NaN
# 4          NaN         NaN        NaN                    NaN
# 5          NaN         NaN        NaN                    NaN
# 6          NaN         NaN        NaN                    NaN
# 7          NaN         NaN        NaN     Washington Wizards
# 8          NaN         NaN        NaN                    NaN
# 9   05/21/2021  09:00 (ET)    MEM@GSW  Golden State Warriors
# 10         NaN         NaN        NaN      Memphis Grizzlies
# 11         NaN         NaN        NaN                    NaN
# 12         NaN         NaN        NaN                    NaN
#
#    Injury Report: 05/20/21 08:30 PM  \
# 0        Player Name Current Status
# 1        Brogdon, Malcolm Available
# 2                  Lamb, Jeremy Out
# 3                 LeVert, Caris Out
# 4          Sumner, Edmond Available
# 5                 Turner, Myles Out
# 6                  Warren, T.J. Out
# 7                  Avdija, Deni Out
# 8                Bryant, Thomas Out
# 9                               NaN
# 10              McDermott, Sean Out
# 11                              NaN
# 12                      Page 1 of 1
#
#                                            Unnamed: 5
# 0                                              Reason
# 1              Injury/Illness - Right Hamstring; Sore
# 2                    Injury/Illness - Left Knee; Sore
# 3                         Health and Safety Protocols
# 4               Injury/Illness - Left Knee; Contusion
# 5   Injury/Illness - Right Toe; Partial Plantar Pl...
# 6         Injury/Illness - Left Foot; Stress Fracture
# 7   Injury/Illness - Right Ankle; Right ankle frac...
# 8         Injury/Illness - Left Knee; Left ACL injury
# 9                                   NOT YET SUBMITTED
# 10               Injury/Illness - Left Foot; Soreness
# 11                                                NaN
# 12                                                NaN

# %%
tabula.read_pdf('2021-05-20_08PM.pdf', stream=True, area=[52.099,16.84,562.561,834.632], pages='all')
# Out:
#     Game Date   Game Time  Matchup                   Team       Player Name  \
# 0  05/20/2021  08:00 (ET)  IND@WAS         Indiana Pacers  Brogdon, Malcolm
# 1         NaN         NaN      NaN                    NaN      Lamb, Jeremy
# 2         NaN         NaN      NaN                    NaN     LeVert, Caris
# 3         NaN         NaN      NaN                    NaN    Sumner, Edmond
# 4         NaN         NaN      NaN                    NaN     Turner, Myles
# 5         NaN         NaN      NaN                    NaN      Warren, T.J.
# 6         NaN         NaN      NaN     Washington Wizards      Avdija, Deni
# 7         NaN         NaN      NaN                    NaN    Bryant, Thomas
# 8  05/21/2021  09:00 (ET)  MEM@GSW  Golden State Warriors               NaN
# 9         NaN         NaN      NaN      Memphis Grizzlies   McDermott, Sean
#
#   Current Status                                             Reason
# 0      Available             Injury/Illness - Right Hamstring; Sore
# 1            Out                   Injury/Illness - Left Knee; Sore
# 2            Out                        Health and Safety Protocols
# 3      Available              Injury/Illness - Left Knee; Contusion
# 4            Out  Injury/Illness - Right Toe; Partial Plantar Pl...
# 5            Out        Injury/Illness - Left Foot; Stress Fracture
# 6            Out  Injury/Illness - Right Ankle; Right ankle frac...
# 7            Out        Injury/Illness - Left Knee; Left ACL injury
# 8            NaN                                  NOT YET SUBMITTED
# 9            Out               Injury/Illness - Left Foot; Soreness

# %%
tabula.read_pdf('2021-05-16_08PM.pdf', stream=True, pages='all')
# Out:
#       Game Date   Game Time  Matchup                    Team  \
# 0    05/16/2021  01:00 (ET)  BOS@NYK          Boston Celtics
# 1           NaN         NaN      NaN                     NaN
# 2           NaN         NaN      NaN                     NaN
# 3           NaN         NaN      NaN                     NaN
# 4           NaN         NaN      NaN                     NaN
# 5           NaN         NaN      NaN                     NaN
# 6           NaN         NaN      NaN                     NaN
# 7           NaN         NaN      NaN         New York Knicks
# 8           NaN         NaN      NaN                     NaN
# 9           NaN         NaN  CHA@WAS       Charlotte Hornets
# 10          NaN         NaN      NaN                     NaN
# 11          NaN         NaN      NaN      Washington Wizards
# 150         NaN         NaN      NaN                     NaN
# 151         NaN         NaN      NaN                     NaN
# 152         NaN         NaN      NaN                     NaN
# 153         NaN         NaN  MIL@CHI           Chicago Bulls
# 154         NaN         NaN      NaN                     NaN
# 155         NaN         NaN      NaN                     NaN
# 156         NaN         NaN      NaN                     NaN
# 157         NaN         NaN      NaN                     NaN
# 158         NaN         NaN      NaN         Milwaukee Bucks
# 159         NaN         NaN  UTA@SAC        Sacramento Kings
# 160         NaN         NaN      NaN                     NaN
# 161         NaN         NaN      NaN                     NaN
# 162         NaN         NaN      NaN                     NaN
# 163         NaN         NaN      NaN                     NaN
# 164         NaN         NaN      NaN                     NaN
# 165         NaN         NaN      NaN                     NaN
# 166         NaN         NaN      NaN               Utah Jazz
#
#                   Player Name  Current Status  \
# 0               Brown, Jaylen             Out
# 1              Fournier, Evan             Out
# 2               Smart, Marcus             Out
# 3               Tatum, Jayson             Out
# 4           Thompson, Tristan             Out
# 5               Walker, Kemba             Out
# 6        Williams III, Robert             Out
# 7          Robinson, Mitchell             Out
# 8               Vildoza, Luca             Out
# 9             Hayward, Gordon             Out
# 10               Martin, Cody             Out
# 11               Avdija, Deni             Out
# 12              Beal, Bradley       Available
# 13             Bryant, Thomas             Out
# 14          Mathews, Garrison       Available
# 15                 Neto, Raul             Out
# 16           Brogdon, Malcolm             Out
# 17             Holiday, Aaron             Out
# 18               Lamb, Jeremy             Out
# 19          Sabonis, Domantas       Available
# 20             Sumner, Edmond             Out
# 21              Turner, Myles             Out
# 22               Warren, T.J.             Out
# 23                Anunoby, OG             Out
# 24              Harris, Jalen             Out
# 25               Hood, Rodney             Out
# 26                Lowry, Kyle             Out
# 27                Player Name  Current Status
# 28             Siakam, Pascal             Out
# 29             VanVleet, Fred             Out
# 30             Watanabe, Yuta             Out
# 31               Watson, Paul             Out
# 32             Ayton, Deandre             Out
# 33              Booker, Devin             Out
# 34               Crowder, Jae             Out
# 35           Johnson, Cameron             Out
# 36               Nader, Abdel             Out
# 37                Paul, Chris             Out
# 38                  Gay, Rudy       Available
# 39           Jeffries, DaQuan             Out
# 40                Lyles, Trey             Out
# 41               Mills, Patty             Out
# 42           Murray, Dejounte       Available
# 43              Samanic, Luka             Out
# 44          Walker IV, Lonnie       Available
# 45             White, Derrick             Out
# 46                Lee, Damion             Out
# 47           Oubre Jr., Kelly             Out
# 48             Thompson, Klay             Out
# 49             Wiseman, James             Out
# 50             Allen, Grayson             Out
# 51            McDermott, Sean             Out
# 52               Brown, Bruce       Available
# 53             Chiozza, Chris             Out
# 54         Dinwiddie, Spencer             Out
# 55                Player Name  Current Status
# 56              Harden, James             Out
# 57                Harris, Joe             Out
# 58       Dellavedova, Matthew             Out
# 59            Garland, Darius             Out
# 60        Hartenstein, Isaiah             Out
# 61                Love, Kevin             Out
# 62           Nance Jr., Larry             Out
# 63            Prince, Taurean             Out
# 64             Stevens, Lamar             Out
# 65             Windler, Dylan             Out
# 66         Bogdanovic, Bogdan             Out
# 67              Capela, Clint             Out
# 68                 Dunn, Kris             Out
# 69          Gallinari, Danilo             Out
# 70           Goodwin, Brandon             Out
# 71             Huerter, Kevin             Out
# 72            Okongwu, Onyeka       Available
# 73               Reddish, Cam             Out
# 74                Snell, Tony       Available
# 75                Young, Trae       Available
# 76             Bradley, Avery             Out
# 77            Brown, Sterling             Out
# 78                Exum, Dante             Out
# 79               Gordon, Eric             Out
# 80          House Jr., Danuel             Out
# 81               Nwaba, David             Out
# 82          Porter Jr., Kevin             Out
# 83                Player Name  Current Status
# 84              Thomas, Khyri             Out
# 85                 Wall, John             Out
# 86            Wood, Christian             Out
# 87                  Bamba, Mo       Available
# 88        Carter Jr., Wendell             Out
# 89   Carter-Williams, Michael             Out
# 90           Ennis III, James             Out
# 91            Fultz, Markelle             Out
# 92              Hampton, R.J.       Available
# 93            Isaac, Jonathan             Out
# 94               Okeke, Chuma             Out
# 95           Porter Jr., Otto             Out
# 96             Ross, Terrence             Out
# 97                Curry, Seth             Out
# 98               Embiid, Joel             Out
# 99               Green, Danny             Out
# 100            Harris, Tobias             Out
# 101           Korkmaz, Furkan       Available
# 102             Milton, Shake       Available
# 103              Simmons, Ben             Out
# 104         Thybulle, Matisse             Out
# 105          Doumbouya, Sekou             Out
# 106          Ellington, Wayne             Out
# 107             Grant, Jerami             Out
# 108            Jackson, Frank             Out
# 109              Joseph, Cory       Available
# 110          McGruder, Rodney             Out
# 111               Player Name  Current Status
# 112        Sirvydis, Deividas             Out
# 113         Smith Jr., Dennis             Out
# 114           Stewart, Isaiah             Out
# 115              Adebayo, Bam             Out
# 116             Ariza, Trevor             Out
# 117             Butler, Jimmy             Out
# 118             Dragic, Goran             Out
# 119           Iguodala, Andre             Out
# 120            Nunn, Kendrick             Out
# 121           Oladipo, Victor             Out
# 122           Yurtseven, Omer             Out
# 123              Kleber, Maxi             Out
# 124                Redick, JJ             Out
# 125            Beasley, Malik             Out
# 126           Culver, Jarrett             Out
# 127              Barton, Will             Out
# 128                Dozier, PJ             Out
# 129             Murray, Jamal             Out
# 130             Collins, Zach             Out
# 131              Coffey, Amir             Out
# 132         Cousins, DeMarcus             Out
# 133             Mann, Terance       Available
# 134            Dort, Luguentz             Out
# 135  Gilgeous-Alexander, Shai             Out
# 136                Jerome, Ty       Available
# 137             Muscala, Mike             Out
# 138              Caruso, Alex       Available
# 139               Player Name  Current Status
# 140            Davis, Anthony       Available
# 141             Dudley, Jared       Available
# 142               Gasol, Marc       Available
# 143             James, LeBron       Available
# 144               Kuzma, Kyle       Available
# 145         McKinnie, Alfonzo       Available
# 146             Adams, Steven             Out
# 147               Ball, Lonzo             Out
# 148                Hart, Josh             Out
# 149           Ingram, Brandon             Out
# 150               Iwundu, Wes             Out
# 151            Johnson, James       Available
# 152          Williamson, Zion             Out
# 153           Brown Jr., Troy             Out
# 154              LaVine, Zach             Out
# 155         Satoransky, Tomas             Out
# 156             Theis, Daniel             Out
# 157           Vucevic, Nikola             Out
# 158          Middleton, Khris             Out
# 159        Bagley III, Marvin        Doubtful
# 160          Barnes, Harrison        Doubtful
# 129                 Injury/Illness - Left Acl; Surgery
# 130       Injury/Illness - Left Ankle; Stress Fracture
# 131                        Health and Safety Protocols
# 132               Injury/Illness - Left Foot; Soreness
# 133                                   Personal Reasons
# 134   Injury/Illness - Right Knee; Patellar Tendinitis
# 135     Injury/Illness - Right Foot; Plantar Fasciitis
# 136                 Injury/Illness - Left Calf; Strain
# 137               Injury/Illness - Right Ankle; Sprain
# 138              Injury/Illness - Right Foot; Soreness
# 139                                             Reason
# 140          Injury/Illness - Left Adductor; Tightness
# 141                   Injury/Illness - Right MCL; Tear
# 142  Injury/Illness - Left Pinkie Finger; Volar Pla...
# 143               Injury/Illness - Right Ankle; Sprain
# 144             Injury/Illness - Lower Back; Tightness
# 145                Injury/Illness - Right Foot; Sprain
# 146           Injury/Illness - Right First MTP; Sprain
# 147               Injury/Illness - Right Thumb; Strain
# 148              Injury/Illness - Right Thumb; Surgery
# 149                Injury/Illness - Left Ankle; Sprain
# 150             Injury/Illness - Left Shoulder; Sprain
# 151              Injury/Illness - Left Knee; Contusion
# 152               Injury/Illness - Left Hand; Fracture
# 153                Injury/Illness - Left Ankle; Sprain
# 154   Injury/Illness - Right Knee; Patellar Tendinitis
# 155                Injury/Illness - Left Ankle; Sprain
# 156                 Injury/Illness - Right Hip; Sprain
# 157                                               Rest
# 158              Injury/Illness - Left Ankle; Soreness
# 159            Injury/Illness - Right Groin; Tightness
# 160          Injury/Illness - Left Adductor; Tightness
# 161                        Health and Safety Protocols
# 162         Injury/Illness - Left Knee; Hyperextension
# 163              Injury/Illness - Right Knee; Soreness
# 164               Injury/Illness - Right Ankle; Sprain
# 165               Injury/Illness - Low Back; Tightness
# 166               Injury/Illness - Right Ankle; Sprain

# %%
dfs = list()
for pdf in tqdm(pdfs):
    print(f'processing {pdf}')
    df = tabula.read_pdf(pdf, stream=True, area=[52.099,16.84,562.561,834.632], pages='all')
    df = clean_injury_report(df)
    dfs.append(df)
# Out:
#   0%|          | 0/205 [00:00<?, ?it/s]
# processing injury_reports/Injury-Report_2020-12-21_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-22_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-23_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-24_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-25_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-26_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-27_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-28_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-29_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-30_08PM.pdf
# processing injury_reports/Injury-Report_2020-12-31_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-29_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-30_08PM.pdf
# processing injury_reports/Injury-Report_2021-01-31_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-02-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-29_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-30_08PM.pdf
# processing injury_reports/Injury-Report_2021-03-31_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-29_08PM.pdf
# processing injury_reports/Injury-Report_2021-04-30_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-29_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-30_08PM.pdf
# processing injury_reports/Injury-Report_2021-05-31_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-04_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-09_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-12_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-15_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-18_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-20_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-21_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-22_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-23_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-24_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-25_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-26_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-27_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-28_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-29_08PM.pdf
# processing injury_reports/Injury-Report_2021-06-30_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-01_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-02_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-03_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-05_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-06_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-07_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-08_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-10_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-11_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-13_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-14_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-16_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-17_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-19_08PM.pdf
# processing injury_reports/Injury-Report_2021-07-20_08PM.pdf

# %%
df = pd.concat(dfs)

# %%
df
# Out:
#      Game Date   Game Time  Matchup                   Team  \
# 0   12/22/2020  07:00 (ET)  GSW@BKN          Brooklyn Nets
# 1   12/22/2020  07:00 (ET)  GSW@BKN  Golden State Warriors
# 2   12/22/2020  07:00 (ET)  GSW@BKN  Golden State Warriors
# 3   12/22/2020  10:00 (ET)  LAC@LAL            LA Clippers
# 0   12/22/2020  07:00 (ET)  GSW@BKN          Brooklyn Nets
# ..         ...         ...      ...                    ...
# 1   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 2   07/20/2021  09:00 (ET)  PHX@MIL           Phoenix Suns
# 0   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 1   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 2   07/20/2021  09:00 (ET)  PHX@MIL           Phoenix Suns
#
#                 Player Name Current Status  \
# 0          Claxton, Nicolas            Out
# 1           Green, Draymond            Out
# 2           Smailagic, Alen            Out
# 3        Morris Sr., Marcus            Out
# 0          Claxton, Nicolas            Out
# ..                      ...            ...
# 1         DiVincenzo, Donte            Out
# 2              Saric, Dario            Out
# 0   Antetokounmpo, Thanasis            Out
# 1         DiVincenzo, Donte            Out
# 2              Saric, Dario            Out
#
#                                        Reason
# 0   Injury/Illness - Right Knee; Tendinopathy
# 1       Injury/Illness - Right foot; soreness
# 2       Injury/Illness - Right Knee; Soreness
# 3       Injury/Illness - Right Knee; Soreness
# 0   Injury/Illness - Right Knee; Tendinopathy
# ..                                        ...
# 1        Injury/Illness - Left Ankle; Surgery
# 2            Injury/Illness - Right Acl; Tear
# 0                 Health and Safety Protocols
# 1        Injury/Illness - Left Ankle; Surgery
# 2            Injury/Illness - Right Acl; Tear
#
# [16401 rows x 7 columns]

# %%
df['Game Date'].nunique()
# Out:
# 192

# %%
len(season_dates)
# Out:
# 212

# %%
df['Team'].unique()
# Out:
# array(['Brooklyn Nets', 'Golden State Warriors', 'LA Clippers',
#        'Charlotte Hornets', 'Cleveland Cavaliers', 'Miami Heat',
#        'Orlando Magic', 'Indiana Pacers', 'New York Knicks',
#        'Washington Wizards', 'Boston Celtics', 'Milwaukee Bucks',
#        'New Orleans Pelicans', 'Toronto Raptors', 'Atlanta Hawks',
#        'Chicago Bulls', 'Detroit Pistons', 'Minnesota Timberwolves',
#        'Houston Rockets', 'Oklahoma City Thunder', 'Memphis Grizzlies',
#        'San Antonio Spurs', 'Denver Nuggets', 'Sacramento Kings',
#        'Portland Trail Blazers', 'Utah Jazz', 'Dallas Mavericks',
#        'Phoenix Suns', 'Los Angeles Lakers', 'Philadelphia 76ers',
#        'Non-NBA Team'], dtype=object)

# %%
df[df['Team'] == 'Non-NBA Team']
# Out:
#     Game Date   Game Time  Matchup          Team Player Name Current Status  \
# 0  03/07/2021  08:00 (ET)  UNK@UNK  Non-NBA Team         NaN            NaN
# 1  03/07/2021  08:00 (ET)  UNK@UNK  Non-NBA Team         NaN            NaN
# 0  03/07/2021  08:00 (ET)  UNK@UNK  Non-NBA Team         NaN            NaN
# 1  03/07/2021  08:00 (ET)  UNK@UNK  Non-NBA Team         NaN            NaN
#
#               Reason
# 0  NOT YET SUBMITTED
# 1  NOT YET SUBMITTED
# 0  NOT YET SUBMITTED
# 1  NOT YET SUBMITTED

# %% [markdown]
# {{ "Famous last words" | fndetail: 10 }}

# %% [markdown]
# {{ "If you happen to find a central place for these, let me know!" | fndetail: 20 }}

# %% [markdown]
# {{ "I'm going to try my best to show the provenance of as much insight as I can here.  I had no idea when the injury reports came out, so I googled it.  Don't be ashamed to do likewise if there's something you need to know!" | fndetail: 30 }}

# %% [markdown]
# {{ "'Decoding the NBA schedule' would certainly be something we could have added to our outline.  This just shows that something as seemingly simple as 'download the PDFs' requires a number of steps that might not be readily apparent!" | fndetail: 40 }}

# %% [markdown]
# {{ '...and sincerely apologize to Adam Silver next time we run into him for the extra traffic on the [nba.com](https://nba.com) servers.' | fndetail: 50 }}

# %% [markdown]
# {{ "The notion that 'something *is* (e.g.) a list because it behaves like a list' is basically the meaning behind [Duck Typing](https://realpython.com/lessons/duck-typing/)" | fndetail: 60 }}

# %% [markdown]
# {{ "If you're thinking 'You should do both', you get a gold star!" | fndetail: 70 }}

# %% [markdown]
# {{ "From manual inspection of the HTTP headers, it looks like nba.com returns a 403 ('Forbidden') when there isn't a valid PDF" | fndetail: 80 }}

# %% [markdown]
# {{ "Or, we could explore the wonderful world of [logging!](https://www.toptal.com/python/in-depth-python-logging)" | fndetail: 90 }}

# %% [markdown]
# ## Footnotes
#
# You can have footnotes in notebooks, however the syntax is different compared to markdown documents. [This guide provides more detail about this syntax](https://github.com/fastai/fastpages/blob/master/_fastpages_docs/NOTEBOOK_FOOTNOTES.md), which looks like this:
#
# ```
# {% raw %}For example, here is a footnote {% fn 1 %}.
# And another {% fn 2 %}
# {{ 'This is the footnote.' | fndetail: 1 }}
# {{ 'This is the other footnote. You can even have a [link](www.github.com)!' | fndetail: 2 }}{% endraw %}
# ```
