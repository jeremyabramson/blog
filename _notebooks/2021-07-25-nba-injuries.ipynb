# %% [markdown]
# # "NBA Injury Report Sports Analytics Project (Part 1)"
# > "Introduction and setup for how to structure a complete sports analytics project"
#
# - toc: true
# - badges: true
# - comments: true
# - author Jeremy Abramson
# - categories: [sports analytics, nba, python, research, projects, injuries]
# - image: images/chart-preview.png

# %% [markdown]
# # Introduction

# %% [markdown]
# ## How To Read This Post

# %% [markdown]
# ## Project Description
#
# It all started with a tweet from basketball analytics legend and Korean cinema aficionado [Ed Kupfer](https://twitter.com/EdKupfer):
# > twitter: https://twitter.com/EdKupfer/status/1385682808174256129
#
# Pretty straightforward, right?
#
# ### Setting Goals
# As per The Kickstarter™️ model, let's define our three goals.
# In this instance, we're going to be somewhat aggressive here, since the creation of our dataset involves some [at this point] unknown tooling.
#
# #### 1.  Fallback Goal
# This one seems pretty obvious:
# > Download and "lift" the data from the NBA Injury Report PDFs into some sort of machine-readable format (`CSV`, `JSON`, etc.)
#
# #### 2.  Baseline Goal
# This one is a little more open ended, but I think a good option might be:
# > Present the data we obtained above in some sort of webapp/dashboard/etc.
#
# #### 3.  Stretch Goal
# As we were pretty aggressive with our first two goals, I think it's perfectly reasonable to not have a Stretch Goal.
# We could say something vague like "analyze the injury data" but in my opinion, that's actually *counterproductive*.
# The reason being that the goal of this project isn't really analysis!
# The goal is is unlock some data in one format, and present it to "the user" in another format that's more amenable for *their* absorption.
# This may not sound very "sexy", but the reality is that this data collection/"chewing"/presenting process is basically [one of the most important things](https://www.sportperformanceanalysis.com/article/communication-with-coaches-as-a-performance-analyst) in sports analytics.
# So unless you have a *specific* analysis in mind, I think it makes sense to not have a Stretch Goal, and to just focus on the first two goals.
# If we do it right, perhaps something interesting will fall out, and we can explore it at that point!

# %% [markdown]
# # Fallback Goal: Downloading and Processing NBA Injury Report PDFs
#
# I find it's helpful to spend a little time — *before* coding! — structuring my thinking about the tasks at hand.
# By virtue of setting goals above, already have two "high level" tasks:
#
# 1. Downloading PDFs
# 2. Processing PDFs.
#
# But we can break those down a little further.
# First off, we can't download anything without knowing *what* to download.
# There doesn't seem to any obvious "central repository" for URLs to injury reports, and since Ed's tweet mentions "just change the date", it seems safe to assume we'll need to build a list of URLs based on dates.
# At this point, I'll note that I'm not sure exactly how to extract the data from the PDFs (minor detail, right?!?)
# But I'm pretty confident it *can* be done, so we'll save a little "Google-fu" for later.
# However, it does seem reasonable to use `Pandas` to post-process our data once we do get it out of the PDF, since it's tabular.
# Lastly, we might want to fancy with [asynchronous requests](https://www.twilio.com/blog/asynchronous-http-requests-in-python-with-aiohttp) (or perhaps not!  It might not be worth the effort, but let's note it here).
#
# Taking all of the above into account, our **Fallback Goal** outline might look like this:
#
# 1. Download PDFs
#     1. Generate list of URLs (dates) to injury report PDFs
#     2. Download URLs from list (do this asynchronously?)
# 2.  Process PDFs
#     1. Extract data from PDF (with what?)
#     2. Post-process data (Pandas)
#
# > Tip: One thing we'll find as we progress is that this outline, as pedantic as it may seem, is incomplete.
# Digging into the above steps, we'll invariably find places where the sub-steps aren't necessarily or obviously entailed by the macro steps.
# If this gets too far out of hand — when, exactly, this happens is a bit of a judgment call — it makes sense to go back and revise the outline.
# For the sake of this blog post, I'm going to go forward with this level of granularity, and we'll see how far we can get.
#
# Now we can tackle these individually, and make sure we're always progressing toward the end goal!

# %% [markdown]
# ## Downloading The Injury Reports
#
# Before we can actually do anything interesting with the injury reports, we need to download them.
# To do that, we need to know where there are.
# After some brief googling, it seems like there really isn't a central repository for these reports, and they're just uploaded one at a time{% fn 1 %}.
#
#
# The one example URL from Ed's tweet looks like this:
# > `https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-04-23_01PM.pdf`
#
# Looks like there's 4 parts to the URL:
# 1. Some boilerplate: `https://ak-static.cms.nba.com/referee/injury/Injury-Report_`
# 2. A date: `2021-04-23`
# 3. A time: `01PM`
# 4. The file extension: `.pdf`
#
# We're only interested in the middle two (the date and the time), as the boilerplate URL and the file extension won't change.  From googling{% fn 2 %} `"nba injury report"` and clicking on [the second link](https://official.nba.com/nba-injury-report-2020-21-season/) it seems like the times may be `1:30 PM`, `5:30 PM` and `8:30 PM`.
# For simplicity, let's just focus on the `8:30PM` file (it's likely to be the most complete anyway).

# %% [markdown]
# ### Building a URL List to Download (Finding Gamedays?)

# %% [markdown]
# Google helped us sort out what we might use for the `time` portion of the URL, but the `date` part is actually a little more complicated than we might like.
# Since, to the best of my knowledge, there's no "central" page that has links to each report, we'll need to know the date for *every* report we want to download.
# According to the [official NBA annoucement](https://official.nba.com/nba-injury-report-2020-21-season/), the dates we're interested in are actually the day *before* game days, except on the second days of back-to-backs, in which case presumably the injury report comes out the day of the game.
#
# This all sounds complicated, and if there's one thing I've learned about projects like this it's that nothing saps enthusiasm like complication and extra effort that doesn't "feel" like it's in the service of what we're trying to  accomplish.
#
# So, given what we know, it seems as if we have two options:
# 1. Get a copy of the NBA schedule, and try to download reports for days we know there's a game
# 2. Just start downloading [a range of?] dates and see what we get
#
# There's nothing wrong with taking a stab at option 1 here, but this project is about injury reports, not the NBA schedule, so we'll start with option 2{% fn 3 %}.

# %% [markdown]
# ### Using `datetime.timedelta` to Construct A List of Dates
# Programmatically dealing with dates can be [frustrating](https://xkcd.com/1179/), and doing so in Python is no exception.
# Despite that, it seems relatively obvious that we need to deal with `date`-like objects here, not just `string` or `numeric` representations of the dates themselves.
# (Trying to "subtract" a day from `01-01-2021` without some internal representation of the calendar seems problematic).
#
# Thinking at a high level, it seems like what we might want to do is build{% fn 3 %} a list of dates, starting at, say, today — or some other reasonable choice, like the end of the NBA season — and work backward until...well, it's not exactly clear how far back we need to go.
# But the notion still seems reasonable: start at a date and count backward day by day, creating a new date each time.
# Luckily, Python has exactly the thing we need to do this: the `timedelta` object.
#
# For our purposes, a `timedelta` object is simply something that allows us to perform arithmetic on `datetime` objects.
# Consider the following:

# %%
from datetime import datetime, timedelta

# Random_date is a datetime object
random_date = datetime.strptime('2011-09-18', '%Y-%m-%d')
# Let's create a new datetime object by subtracting a timedelta object
# Note that we're using the "days" parameter.  Try experimenting with other values!
new_date = random_date - timedelta(days=10)

print(f"Ten days before {random_date} is {new_date}")
# Out:
# Ten days before 2011-09-18 00:00:00 is 2011-09-08 00:00:00

# %% [markdown]
# > Tip: Adding or subtracting `datetime` and `timedelta` objects from each other can be tricky.  Expand the code below to see examples of what is valid, and what returns an error.  Try playing with *negative* `timedelta` values!

# %% [markdown]
# The 2021 NBA season [ended on July 20th](https://www.youtube.com/watch?v=9O920AD-teU), and from manual testing, [https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf](https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf) is a valid link (the next day, unsurprisingly, is not).
# So let's start there, and count backward until we reach the day *before* the [start](https://en.wikipedia.org/wiki/2020–21_NBA_season) of the season, which would be December 21st, 2020.

# %%
season_start = datetime.strptime('2020-12-21', '%Y-%m-%d')
season_end = datetime.strptime('2021-07-20', '%Y-%m-%d')
season_duration = season_end - season_start
# season_duraction is a timedelta object
print(f'{season_duration=} is of type {type(season_duration)}')
# Out:
# season_duration=datetime.timedelta(days=211) is of type <class 'datetime.timedelta'>

# %%
import pandas as pd
test = pd.date_range(start='12-21-2020', end='07-20-2021')
test[0].date()
# Out:
# datetime.date(2020, 12, 21)

# %%
for thing in test:
    print(datetime.strftime(thing.date(), '%Y-%m-%d'))
# Out:
# 2020-12-21
# 2020-12-22
# 2020-12-23
# 2020-12-24
# 2020-12-25
# 2020-12-26
# 2020-12-27
# 2020-12-28
# 2020-12-29
# 2020-12-30
# 2020-12-31
# 2021-01-01
# 2021-01-02
# 2021-01-03
# 2021-01-04
# 2021-01-05
# 2021-01-06
# 2021-01-07
# 2021-01-08
# 2021-01-09
# 2021-01-10
# 2021-01-11
# 2021-01-12
# 2021-01-13
# 2021-01-14
# 2021-01-15
# 2021-01-16
# 2021-01-17
# 2021-01-18
# 2021-01-19
# 2021-01-20
# 2021-01-21
# 2021-01-22
# 2021-01-23
# 2021-01-24
# 2021-01-25
# 2021-01-26
# 2021-01-27
# 2021-01-28
# 2021-01-29
# 2021-01-30
# 2021-01-31
# 2021-02-01
# 2021-02-02
# 2021-02-03
# 2021-02-04
# 2021-02-05
# 2021-02-06
# 2021-02-07
# 2021-02-08
# 2021-02-09
# 2021-02-10
# 2021-02-11
# 2021-02-12
# 2021-02-13
# 2021-02-14
# 2021-02-15
# 2021-02-16
# 2021-02-17
# 2021-02-18
# 2021-02-19
# 2021-02-20
# 2021-02-21
# 2021-02-22
# 2021-02-23
# 2021-02-24
# 2021-02-25
# 2021-02-26
# 2021-02-27
# 2021-02-28
# 2021-03-01
# 2021-03-02
# 2021-03-03
# 2021-03-04
# 2021-03-05
# 2021-03-06
# 2021-03-07
# 2021-03-08
# 2021-03-09
# 2021-03-10
# 2021-03-11
# 2021-03-12
# 2021-03-13
# 2021-03-14
# 2021-03-15
# 2021-03-16
# 2021-03-17
# 2021-03-18
# 2021-03-19
# 2021-03-20
# 2021-03-21
# 2021-03-22
# 2021-03-23
# 2021-03-24
# 2021-03-25
# 2021-03-26
# 2021-03-27
# 2021-03-28
# 2021-03-29
# 2021-03-30
# 2021-03-31
# 2021-04-01
# 2021-04-02
# 2021-04-03
# 2021-04-04
# 2021-04-05
# 2021-04-06
# 2021-04-07
# 2021-04-08
# 2021-04-09
# 2021-04-10
# 2021-04-11
# 2021-04-12
# 2021-04-13
# 2021-04-14
# 2021-04-15
# 2021-04-16
# 2021-04-17
# 2021-04-18
# 2021-04-19
# 2021-04-20
# 2021-04-21
# 2021-04-22
# 2021-04-23
# 2021-04-24
# 2021-04-25
# 2021-04-26
# 2021-04-27
# 2021-04-28
# 2021-04-29
# 2021-04-30
# 2021-05-01
# 2021-05-02
# 2021-05-03
# 2021-05-04
# 2021-05-05
# 2021-05-06
# 2021-05-07
# 2021-05-08
# 2021-05-09
# 2021-05-10
# 2021-05-11
# 2021-05-12
# 2021-05-13
# 2021-05-14
# 2021-05-15
# 2021-05-16
# 2021-05-17
# 2021-05-18
# 2021-05-19
# 2021-05-20
# 2021-05-21
# 2021-05-22
# 2021-05-23
# 2021-05-24
# 2021-05-25
# 2021-05-26
# 2021-05-27
# 2021-05-28
# 2021-05-29
# 2021-05-30
# 2021-05-31
# 2021-06-01
# 2021-06-02
# 2021-06-03
# 2021-06-04
# 2021-06-05
# 2021-06-06
# 2021-06-07
# 2021-06-08
# 2021-06-09
# 2021-06-10
# 2021-06-11
# 2021-06-12
# 2021-06-13
# 2021-06-14
# 2021-06-15
# 2021-06-16
# 2021-06-17
# 2021-06-18
# 2021-06-19
# 2021-06-20
# 2021-06-21
# 2021-06-22
# 2021-06-23
# 2021-06-24
# 2021-06-25
# 2021-06-26
# 2021-06-27
# 2021-06-28
# 2021-06-29
# 2021-06-30
# 2021-07-01
# 2021-07-02
# 2021-07-03
# 2021-07-04
# 2021-07-05
# 2021-07-06
# 2021-07-07
# 2021-07-08
# 2021-07-09
# 2021-07-10
# 2021-07-11
# 2021-07-12
# 2021-07-13
# 2021-07-14
# 2021-07-15
# 2021-07-16
# 2021-07-17
# 2021-07-18
# 2021-07-19
# 2021-07-20

# %% [markdown]
# Now, constructing the list of dates is actually a little tricky.
# Unfortunately, we can't just "increment" `season_start` until it reaches `season_end` (that would be too easy).
# We basically have to turn our `season_duration` — which is a `timedelta` object — into an integral `range`, and then we iterate over *that*, subtracting a day for each value in the range.
# To do this, we use the `.days` attribute of the `timedelta` object.
# That gives us an `integer` representation of the how many days are between the two dates used to create the `timedelta` in the first place.
# We then convert this integral number of days *back* into a `timedelta`, which we subtract from our `season_end` variable.
# Confused?  Hopefully the code will help clarify:

# %%
# We'll store our dates here
season_dates = list()
# Convert the timedelta into an integral range, from 0 to the number of days in season_duration (211)
for day_number in range(season_duration.days):
    # Subtract day_number of days from our season endpoint (after converting to a timedelta)
    gameday = season_end - timedelta(days=day_number)
    # Append this new datetime to our list
    season_dates.append(gameday)
print(f'season_dates spans from {season_dates[0]} to {season_dates[-1]} with length {len(season_dates)}')
# Out:
# season_dates spans from 2021-07-20 00:00:00 to 2020-12-22 00:00:00 with length 211

# %% [markdown]
# Uh oh, we're off by one, and a day short!
# Makes sense, since we're only iterating 211 times, so we lose one of the endpoints.
# Fixing that, and converting the above to a list comprehension, we get:

# %%
# season_duration.days+1 gives us the range we're looking for
season_dates = [season_end - timedelta(days=day_number) for day_number in range(season_duration.days+1)]
print(f'season_dates spans from {season_dates[0]} to {season_dates[-1]} with length {len(season_dates)}')
# Out:
# season_dates spans from 2021-07-20 00:00:00 to 2020-12-21 00:00:00 with length 212

# %% [markdown]
# That's more like it.
# Finally, we have our list of dates to use in our URLs.
# On to downloading!

# %% [markdown]
# # Downloading The Injury Reports

# %% [markdown]
# For simplicity's sake, we'll just use the `requests` module to download the PDFs sequentially.
# Later, we can see about using *asynchronous* requests to greatly speed up our downloads, but for now let's just do things one at a time.
#
# We need to do three things:
# 1. Construct a URL from the dates we generated above
# 2. Download the PDF at the URL (if it exists)
# 3. Save it to disk; eventually we'll need to process the PDFs, but for now let's just store them

# %% [markdown]
# ## Constructing an Injury Report URL
# As we saw [above](https://jeremyabramson.github.io/blog/sports%20analytics/nba/python/research/projects/injuries/2021/07/25/nba-injuries.html#Decoding-the-Filename-Schema-From-the-URL), the URL has 4 parts.
# For simplicity, let's only worry about gathering the 8PM report, which is the one that's most likely to have all the relevant information for the day.
#
# As a reminder, the URL's look like this:
# > https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf

# %% [markdown]
# Let's define variables for the parts of the URL that are static (for now, we may want to download other `report_time` values later):

# %%
# We don't need to define a variable for the extension
url_stem = 'https://ak-static.cms.nba.com/referee/injury/Injury-Report_'
report_time = '08PM'

# %% [markdown]
# And let's build an example URL, using the first date from the `season_dates` list we created above:

# %%
print(f'{url_stem}{season_dates[0]}_{report_time}.pdf')
# Out:
# https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20 00:00:00_08PM.pdf

# %% [markdown]
# Almost, but not quite!
# We need to convert our date back to a string, using `strftime()` ("string from time").
# We use the exact same `format string` that we used when we made the call to `strptime()` ("string parse time") previously, in this case `'%Y-%m-%d'`.

# %%
# Convert the datetime object back to a string for our URL
print(f'{url_stem}{datetime.strftime(season_dates[0], "%Y-%m-%d")}_{report_time}.pdf')
# Out:
# https://ak-static.cms.nba.com/referee/injury/Injury-Report_2021-07-20_08PM.pdf

# %% [markdown]
# If you copy and paste that link into the search bar — or click on it if you're viewing this in a notebook — you should be greeted be the injury report for Game 6 of the NBA finals.
# Now we just need to iterate through the `season_dates` list and download each PDF, if it exists.
# We could do this lazily, with something simple like:
# ```python
# import requests
# # Loop through our dates lists
# for gameday in season_dates:
#     # Construct the URL and download the PDF
#     resp = requests.get(f'{url_stem}{datetime.strftime(gameday, "%Y-%m-%d")}_{report_time}.pdf')
#     # Write to disk
#     with open(f'{datetime.strftime(gameday, "%Y-%m-%d")}_{report_time}.pdf', 'wb') as f:
#         f.write(resp.content)
# ```
#
# With the code above, what happens if there's no report for a specific day?
# Or if there's a network error, either with the server or our own internet?
#
# In general, it's a good idea to program a little defensively when accessing network assets, especially in cases like this, where there's a high likelihood of accessing an "invalid" URL, with nothing on the other end to download.
# It's easy to imagine the downstream PDF processing — that we haven't written yet :-) — breaking when it tries to open an empty file, for example.
# We could try to handle the error at that point, but it's probably better to do it here, and only write valid files{% fn 5 %}.
#
# We'll assume that accessing a URL without a valid injury report PDF will return an [HTTP status code](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes) of something other than **200**, which is "success" {% fn 6 %}.
# To handle this, we'll use the `requests` library's `raise_for_status()` method, which can raise an exception when we get a non-success status code.
# We can then catch that exception, and skip writing the file.
#
# Let's add that to the code above, refactor things a skosh to be a little cleaner, and bring in some code from above for clarity:

# %% [markdown]
# > Important: Note that the `.raise_for_status()` call is the one that raises the exception, **not** the `.get()` call!  Make sure `raise_for_status()` is inside your `try/except` block!

# %%
import requests
url_stem = 'https://ak-static.cms.nba.com/referee/injury/Injury-Report_'
report_time = '08PM'
# Loop through our dates lists
for gameday in season_dates:
    # Construct a URL
    url = f'{url_stem}{datetime.strftime(gameday, "%Y-%m-%d")}_{report_time}.pdf'
    # Make the request to download the PDF
    resp = requests.get(url)
    try:
        resp.raise_for_status()
    # This is the exception to catch for non-200 response codes; this won't necessarily catch network errors
    except requests.HTTPError:
        print(f'No valid PDF on {gameday}, removing from list')
        season_dates.remove(gameday)
    # The "else" block of a try/except happens if there isn't an exception
    else:
        filename = f'{datetime.strftime(gameday, "%Y-%m-%d")}_{report_time}.pdf'
        # Write to disk
        print(f'Writing PDF for {gameday}')
        with open(filename, 'wb') as f:
            f.write(resp.content)
# Out:
# Writing PDF for 2021-07-20 00:00:00
# Writing PDF for 2021-07-19 00:00:00
# No valid PDF on 2021-07-18 00:00:00, removing from list
# Writing PDF for 2021-07-16 00:00:00
# No valid PDF on 2021-07-15 00:00:00, removing from list
# Writing PDF for 2021-07-13 00:00:00
# No valid PDF on 2021-07-12 00:00:00, removing from list
# Writing PDF for 2021-07-10 00:00:00
# No valid PDF on 2021-07-09 00:00:00, removing from list
# Writing PDF for 2021-07-07 00:00:00
# Writing PDF for 2021-07-06 00:00:00
# Writing PDF for 2021-07-05 00:00:00
# No valid PDF on 2021-07-04 00:00:00, removing from list
# Writing PDF for 2021-07-02 00:00:00
# Writing PDF for 2021-07-01 00:00:00
# Writing PDF for 2021-06-30 00:00:00
# Writing PDF for 2021-06-29 00:00:00
# Writing PDF for 2021-06-28 00:00:00
# Writing PDF for 2021-06-27 00:00:00
# Writing PDF for 2021-06-26 00:00:00
# Writing PDF for 2021-06-25 00:00:00
# Writing PDF for 2021-06-24 00:00:00
# Writing PDF for 2021-06-23 00:00:00
# Writing PDF for 2021-06-22 00:00:00
# Writing PDF for 2021-06-21 00:00:00
# Writing PDF for 2021-06-20 00:00:00
# Writing PDF for 2021-06-19 00:00:00
# Writing PDF for 2021-06-18 00:00:00
# Writing PDF for 2021-06-17 00:00:00
# Writing PDF for 2021-06-16 00:00:00
# Writing PDF for 2021-06-15 00:00:00
# Writing PDF for 2021-06-14 00:00:00
# Writing PDF for 2021-06-13 00:00:00
# Writing PDF for 2021-06-12 00:00:00
# Writing PDF for 2021-06-11 00:00:00
# Writing PDF for 2021-06-10 00:00:00
# Writing PDF for 2021-06-09 00:00:00
# Writing PDF for 2021-06-08 00:00:00
# Writing PDF for 2021-06-07 00:00:00
# Writing PDF for 2021-06-06 00:00:00
# Writing PDF for 2021-06-05 00:00:00
# Writing PDF for 2021-06-04 00:00:00
# Writing PDF for 2021-06-03 00:00:00
# Writing PDF for 2021-06-02 00:00:00
# Writing PDF for 2021-06-01 00:00:00
# Writing PDF for 2021-05-31 00:00:00
# Writing PDF for 2021-05-30 00:00:00
# Writing PDF for 2021-05-29 00:00:00
# Writing PDF for 2021-05-28 00:00:00
# Writing PDF for 2021-05-27 00:00:00
# Writing PDF for 2021-05-26 00:00:00
# Writing PDF for 2021-05-25 00:00:00
# Writing PDF for 2021-05-24 00:00:00
# Writing PDF for 2021-05-23 00:00:00
# Writing PDF for 2021-05-22 00:00:00
# Writing PDF for 2021-05-21 00:00:00
# Writing PDF for 2021-05-20 00:00:00
# Writing PDF for 2021-05-19 00:00:00
# Writing PDF for 2021-05-18 00:00:00
# Writing PDF for 2021-05-17 00:00:00
# Writing PDF for 2021-05-16 00:00:00
# Writing PDF for 2021-05-15 00:00:00
# Writing PDF for 2021-05-14 00:00:00
# Writing PDF for 2021-05-13 00:00:00
# Writing PDF for 2021-05-12 00:00:00
# Writing PDF for 2021-05-11 00:00:00
# Writing PDF for 2021-05-10 00:00:00
# Writing PDF for 2021-05-09 00:00:00
# Writing PDF for 2021-05-08 00:00:00
# Writing PDF for 2021-05-07 00:00:00
# Writing PDF for 2021-05-06 00:00:00
# Writing PDF for 2021-05-05 00:00:00
# Writing PDF for 2021-05-04 00:00:00
# Writing PDF for 2021-05-03 00:00:00
# Writing PDF for 2021-05-02 00:00:00
# Writing PDF for 2021-05-01 00:00:00
# Writing PDF for 2021-04-30 00:00:00
# Writing PDF for 2021-04-29 00:00:00
# Writing PDF for 2021-04-28 00:00:00
# Writing PDF for 2021-04-27 00:00:00
# Writing PDF for 2021-04-26 00:00:00
# Writing PDF for 2021-04-25 00:00:00
# Writing PDF for 2021-04-24 00:00:00
# Writing PDF for 2021-04-23 00:00:00
# Writing PDF for 2021-04-22 00:00:00
# Writing PDF for 2021-04-21 00:00:00
# Writing PDF for 2021-04-20 00:00:00
# Writing PDF for 2021-04-19 00:00:00
# Writing PDF for 2021-04-18 00:00:00
# Writing PDF for 2021-04-17 00:00:00
# Writing PDF for 2021-04-16 00:00:00
# Writing PDF for 2021-04-15 00:00:00
# Writing PDF for 2021-04-14 00:00:00
# Writing PDF for 2021-04-13 00:00:00
# Writing PDF for 2021-04-12 00:00:00
# Writing PDF for 2021-04-11 00:00:00
# Writing PDF for 2021-04-10 00:00:00
# Writing PDF for 2021-04-09 00:00:00
# Writing PDF for 2021-04-08 00:00:00
# Writing PDF for 2021-04-07 00:00:00
# Writing PDF for 2021-04-06 00:00:00
# Writing PDF for 2021-04-05 00:00:00
# Writing PDF for 2021-04-04 00:00:00
# Writing PDF for 2021-04-03 00:00:00
# Writing PDF for 2021-04-02 00:00:00
# Writing PDF for 2021-04-01 00:00:00
# Writing PDF for 2021-03-31 00:00:00
# Writing PDF for 2021-03-30 00:00:00
# Writing PDF for 2021-03-29 00:00:00
# Writing PDF for 2021-03-28 00:00:00
# Writing PDF for 2021-03-27 00:00:00
# Writing PDF for 2021-03-26 00:00:00
# Writing PDF for 2021-03-25 00:00:00
# Writing PDF for 2021-03-24 00:00:00
# Writing PDF for 2021-03-23 00:00:00
# Writing PDF for 2021-03-22 00:00:00
# Writing PDF for 2021-03-21 00:00:00
# Writing PDF for 2021-03-20 00:00:00
# Writing PDF for 2021-03-19 00:00:00
# Writing PDF for 2021-03-18 00:00:00
# Writing PDF for 2021-03-17 00:00:00
# Writing PDF for 2021-03-16 00:00:00
# Writing PDF for 2021-03-15 00:00:00
# Writing PDF for 2021-03-14 00:00:00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-136-955ec92f21d6> in <module>
#       7     url = f'{url_stem}{datetime.strftime(gameday, "%Y-%m-%d")}_{report_time}.pdf'
#       8     # Make the request to download the PDF
# ----> 9     resp = requests.get(url)
#      10     try:
#      11         resp.raise_for_status()
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/miniconda3/envs/sports/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~/miniconda3/envs/sports/lib/python3.8/http/client.py in getresponse(self)
#    1345         try:
#    1346             try:
# -> 1347                 response.begin()
#    1348             except ConnectionError:
#    1349                 self.close()
#
# ~/miniconda3/envs/sports/lib/python3.8/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~/miniconda3/envs/sports/lib/python3.8/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~/miniconda3/envs/sports/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/miniconda3/envs/sports/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniconda3/envs/sports/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# # Extracting Tables from PDF Files
#
# Now that we have our 212 injury report PDFs, it's time to extract the data in the tables.
# While I've briefly played around with optical character recognition (OCR) tools like [Tesseract](https://github.com/tesseract-ocr/tesseract), strict OCR seemed like a bad fit.
# Other than that, I wasn't sure what tool to use, which means...google to the rescue!
#
# At first, I [foolishly] googled for *\"python parse PDF\"*, and eventually *\"python parse PDF text\"*, thinking  it'd be obvious I meant "parse PDF **tables**".
# Apparently clairvoyance isn't quite built into google [yet], so I ended up checking out packages such as [PyPDF2](https://pypi.org/project/PyPDF2/), [pdfreader](https://pypi.org/project/pdfreader/), and eventually [pdfminer.six](pdfminer.six).
# These tools seem much more oriented toward programmatically creating and manipulating PDF documents, than extracting text.
# Eventually down the list of google results I came upon [this stackoverflow post](https://stackoverflow.com/questions/34837707/how-to-extract-text-from-a-pdf-file).
# One of the answers mentioned [tabula](https://tabula.technology) and converting PDF tables to dataframes.
# This seemed promising,

# %%
import tabula
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)

# %%
tabula.read_pdf("2021-07-20_08PM.pdf", pages='all')
# Out:
#       Game Date          Game Time  Matchup  \
# 0    07/20/2021         09:00 (ET)  PHX@MIL
# 1           NaN  DiVincenzo, Donte      Out
# 2  Phoenix Suns       Saric, Dario      Out
#
#                                    Team              Player Name  \
# 0                       Milwaukee Bucks  Antetokounmpo, Thanasis
# 1  Injury/Illness - Left Ankle; Surgery                      NaN
# 2      Injury/Illness - Right Acl; Tear                      NaN
#
#   Current Status                       Reason
# 0            Out  Health and Safety Protocols
# 1            NaN                          NaN
# 2            NaN                          NaN

# %%
df = tabula.read_pdf("2021-03-20_08PM.pdf", stream=True, pages='all')

# %%
df = df.drop(df.loc[df['Game Date'] == 'Game Date'].index).reset_index(drop=True)
df['Game Date'] = df['Game Date'].fillna(method='pad')
df['Matchup'] = df['Matchup'].fillna(method='pad')
df['Team'] = df['Team'].fillna(method='pad')
df['Game Time'] = df['Game Time'].fillna(method='pad')
#df[['Last Name', 'First Name']] = df['Player Name'].str.split(',', expand=True)
#df = df.drop(columns=['Player Name']))

# %%
def clean_injury_report(df):
    df = df.drop(df.loc[df['Game Date'] == 'Game Date'].index).reset_index(drop=True)
    df['Game Date'] = df['Game Date'].fillna(method='pad')
    df['Matchup'] = df['Matchup'].fillna(method='pad')
    df['Team'] = df['Team'].fillna(method='pad')
    df['Game Time'] = df['Game Time'].fillna(method='pad')
    return df

# %%
from pathlib import Path
from tqdm.notebook import tqdm

# %%
pdfs = sorted(list(Path('./').glob('*.pdf')))

# %%
tabula.read_pdf('2021-05-20_08PM.pdf', stream=True, guess=False, pages='all')
# Out:
#     Unnamed: 0  Unnamed: 1 Unnamed: 2             Unnamed: 3  \
# 0    Game Date   Game Time    Matchup                   Team
# 1   05/20/2021  08:00 (ET)    IND@WAS         Indiana Pacers
# 2          NaN         NaN        NaN                    NaN
# 3          NaN         NaN        NaN                    NaN
# 4          NaN         NaN        NaN                    NaN
# 5          NaN         NaN        NaN                    NaN
# 6          NaN         NaN        NaN                    NaN
# 7          NaN         NaN        NaN     Washington Wizards
# 8          NaN         NaN        NaN                    NaN
# 9   05/21/2021  09:00 (ET)    MEM@GSW  Golden State Warriors
# 10         NaN         NaN        NaN      Memphis Grizzlies
# 11         NaN         NaN        NaN                    NaN
# 12         NaN         NaN        NaN                    NaN
#
#    Injury Report: 05/20/21 08:30 PM  \
# 0        Player Name Current Status
# 1        Brogdon, Malcolm Available
# 2                  Lamb, Jeremy Out
# 3                 LeVert, Caris Out
# 4          Sumner, Edmond Available
# 5                 Turner, Myles Out
# 6                  Warren, T.J. Out
# 7                  Avdija, Deni Out
# 8                Bryant, Thomas Out
# 9                               NaN
# 10              McDermott, Sean Out
# 11                              NaN
# 12                      Page 1 of 1
#
#                                            Unnamed: 5
# 0                                              Reason
# 1              Injury/Illness - Right Hamstring; Sore
# 2                    Injury/Illness - Left Knee; Sore
# 3                         Health and Safety Protocols
# 4               Injury/Illness - Left Knee; Contusion
# 5   Injury/Illness - Right Toe; Partial Plantar Pl...
# 6         Injury/Illness - Left Foot; Stress Fracture
# 7   Injury/Illness - Right Ankle; Right ankle frac...
# 8         Injury/Illness - Left Knee; Left ACL injury
# 9                                   NOT YET SUBMITTED
# 10               Injury/Illness - Left Foot; Soreness
# 11                                                NaN
# 12                                                NaN

# %%
tabula.read_pdf('2021-05-20_08PM.pdf', stream=True, area=[52.099,16.84,562.561,834.632], pages='all')
# Out:
#     Game Date   Game Time  Matchup                   Team       Player Name  \
# 0  05/20/2021  08:00 (ET)  IND@WAS         Indiana Pacers  Brogdon, Malcolm
# 1         NaN         NaN      NaN                    NaN      Lamb, Jeremy
# 2         NaN         NaN      NaN                    NaN     LeVert, Caris
# 3         NaN         NaN      NaN                    NaN    Sumner, Edmond
# 4         NaN         NaN      NaN                    NaN     Turner, Myles
# 5         NaN         NaN      NaN                    NaN      Warren, T.J.
# 6         NaN         NaN      NaN     Washington Wizards      Avdija, Deni
# 7         NaN         NaN      NaN                    NaN    Bryant, Thomas
# 8  05/21/2021  09:00 (ET)  MEM@GSW  Golden State Warriors               NaN
# 9         NaN         NaN      NaN      Memphis Grizzlies   McDermott, Sean
#
#   Current Status                                             Reason
# 0      Available             Injury/Illness - Right Hamstring; Sore
# 1            Out                   Injury/Illness - Left Knee; Sore
# 2            Out                        Health and Safety Protocols
# 3      Available              Injury/Illness - Left Knee; Contusion
# 4            Out  Injury/Illness - Right Toe; Partial Plantar Pl...
# 5            Out        Injury/Illness - Left Foot; Stress Fracture
# 6            Out  Injury/Illness - Right Ankle; Right ankle frac...
# 7            Out        Injury/Illness - Left Knee; Left ACL injury
# 8            NaN                                  NOT YET SUBMITTED
# 9            Out               Injury/Illness - Left Foot; Soreness

# %%
tabula.read_pdf('2021-05-16_08PM.pdf', stream=True, pages='all')
# Out:
#       Game Date   Game Time  Matchup                    Team  \
# 0    05/16/2021  01:00 (ET)  BOS@NYK          Boston Celtics
# 1           NaN         NaN      NaN                     NaN
# 2           NaN         NaN      NaN                     NaN
# 3           NaN         NaN      NaN                     NaN
# 4           NaN         NaN      NaN                     NaN
# 5           NaN         NaN      NaN                     NaN
# 6           NaN         NaN      NaN                     NaN
# 7           NaN         NaN      NaN         New York Knicks
# 8           NaN         NaN      NaN                     NaN
# 9           NaN         NaN  CHA@WAS       Charlotte Hornets
# 10          NaN         NaN      NaN                     NaN
# 11          NaN         NaN      NaN      Washington Wizards
# 12          NaN         NaN      NaN                     NaN
# 13          NaN         NaN      NaN                     NaN
# 14          NaN         NaN      NaN                     NaN
# 15          NaN         NaN      NaN                     NaN
# 16          NaN         NaN  IND@TOR          Indiana Pacers
# 17          NaN         NaN      NaN                     NaN
# 18          NaN         NaN      NaN                     NaN
# 19          NaN         NaN      NaN                     NaN
# 20          NaN         NaN      NaN                     NaN
# 21          NaN         NaN      NaN                     NaN
# 22          NaN         NaN      NaN                     NaN
# 23          NaN         NaN      NaN         Toronto Raptors
# 24          NaN         NaN      NaN                     NaN
# 25          NaN         NaN      NaN                     NaN
# 26          NaN         NaN      NaN                     NaN
# 27    Game Date   Game Time  Matchup                    Team
# 28          NaN         NaN      NaN                     NaN
# 29          NaN         NaN      NaN                     NaN
# 30          NaN         NaN      NaN                     NaN
# 31          NaN         NaN      NaN                     NaN
# 32          NaN  02:00 (ET)  PHX@SAS            Phoenix Suns
# 33          NaN         NaN      NaN                     NaN
# 34          NaN         NaN      NaN                     NaN
# 35          NaN         NaN      NaN                     NaN
# 36          NaN         NaN      NaN                     NaN
# 37          NaN         NaN      NaN                     NaN
# 38          NaN         NaN      NaN       San Antonio Spurs
# 39          NaN         NaN      NaN                     NaN
# 40          NaN         NaN      NaN                     NaN
# 41          NaN         NaN      NaN                     NaN
# 42          NaN         NaN      NaN                     NaN
# 43          NaN         NaN      NaN                     NaN
# 44          NaN         NaN      NaN                     NaN
# 45          NaN         NaN      NaN                     NaN
# 46          NaN  03:30 (ET)  MEM@GSW   Golden State Warriors
# 47          NaN         NaN      NaN                     NaN
# 48          NaN         NaN      NaN                     NaN
# 49          NaN         NaN      NaN                     NaN
# 50          NaN         NaN      NaN       Memphis Grizzlies
# 51          NaN         NaN      NaN                     NaN
# 52          NaN  07:00 (ET)  CLE@BKN           Brooklyn Nets
# 53          NaN         NaN      NaN                     NaN
# 54          NaN         NaN      NaN                     NaN
# 55    Game Date   Game Time  Matchup                    Team
# 56          NaN         NaN      NaN                     NaN
# 57          NaN         NaN      NaN                     NaN
# 58          NaN         NaN      NaN     Cleveland Cavaliers
# 59          NaN         NaN      NaN                     NaN
# 60          NaN         NaN      NaN                     NaN
# 61          NaN         NaN      NaN                     NaN
# 62          NaN         NaN      NaN                     NaN
# 63          NaN         NaN      NaN                     NaN
# 64          NaN         NaN      NaN                     NaN
# 65          NaN         NaN      NaN                     NaN
# 66          NaN         NaN  HOU@ATL           Atlanta Hawks
# 67          NaN         NaN      NaN                     NaN
# 68          NaN         NaN      NaN                     NaN
# 69          NaN         NaN      NaN                     NaN
# 70          NaN         NaN      NaN                     NaN
# 71          NaN         NaN      NaN                     NaN
# 72          NaN         NaN      NaN                     NaN
# 73          NaN         NaN      NaN                     NaN
# 74          NaN         NaN      NaN                     NaN
# 75          NaN         NaN      NaN                     NaN
# 76          NaN         NaN      NaN         Houston Rockets
# 77          NaN         NaN      NaN                     NaN
# 78          NaN         NaN      NaN                     NaN
# 79          NaN         NaN      NaN                     NaN
# 80          NaN         NaN      NaN                     NaN
# 81          NaN         NaN      NaN                     NaN
# 82          NaN         NaN      NaN                     NaN
# 83    Game Date   Game Time  Matchup                    Team
# 84          NaN         NaN      NaN                     NaN
# 85          NaN         NaN      NaN                     NaN
# 86          NaN         NaN      NaN                     NaN
# 87          NaN         NaN  ORL@PHI           Orlando Magic
# 88          NaN         NaN      NaN                     NaN
# 89          NaN         NaN      NaN                     NaN
# 90          NaN         NaN      NaN                     NaN
# 91          NaN         NaN      NaN                     NaN
# 92          NaN         NaN      NaN                     NaN
# 93          NaN         NaN      NaN                     NaN
# 94          NaN         NaN      NaN                     NaN
# 95          NaN         NaN      NaN                     NaN
# 96          NaN         NaN      NaN                     NaN
# 97          NaN         NaN      NaN      Philadelphia 76ers
# 98          NaN         NaN      NaN                     NaN
# 99          NaN         NaN      NaN                     NaN
# 100         NaN         NaN      NaN                     NaN
# 101         NaN         NaN      NaN                     NaN
# 102         NaN         NaN      NaN                     NaN
# 103         NaN         NaN      NaN                     NaN
# 104         NaN         NaN      NaN                     NaN
# 105         NaN  08:00 (ET)  MIA@DET         Detroit Pistons
# 106         NaN         NaN      NaN                     NaN
# 107         NaN         NaN      NaN                     NaN
# 108         NaN         NaN      NaN                     NaN
# 109         NaN         NaN      NaN                     NaN
# 110         NaN         NaN      NaN                     NaN
# 111   Game Date   Game Time  Matchup                    Team
# 112         NaN         NaN      NaN                     NaN
# 113         NaN         NaN      NaN                     NaN
# 114         NaN         NaN      NaN                     NaN
# 115         NaN         NaN      NaN              Miami Heat
# 116         NaN         NaN      NaN                     NaN
# 117         NaN         NaN      NaN                     NaN
# 118         NaN         NaN      NaN                     NaN
# 119         NaN         NaN      NaN                     NaN
# 120         NaN         NaN      NaN                     NaN
# 121         NaN         NaN      NaN                     NaN
# 122         NaN         NaN      NaN                     NaN
# 123         NaN  09:00 (ET)  DAL@MIN        Dallas Mavericks
# 124         NaN         NaN      NaN                     NaN
# 125         NaN         NaN      NaN  Minnesota Timberwolves
# 126         NaN         NaN      NaN                     NaN
# 127         NaN         NaN  DEN@POR          Denver Nuggets
# 128         NaN         NaN      NaN                     NaN
# 129         NaN         NaN      NaN                     NaN
# 130         NaN         NaN      NaN  Portland Trail Blazers
# 131         NaN         NaN  LAC@OKC             LA Clippers
# 132         NaN         NaN      NaN                     NaN
# 133         NaN         NaN      NaN                     NaN
# 134         NaN         NaN      NaN   Oklahoma City Thunder
# 135         NaN         NaN      NaN                     NaN
# 136         NaN         NaN      NaN                     NaN
# 137         NaN         NaN      NaN                     NaN
# 138         NaN         NaN  LAL@NOP      Los Angeles Lakers
# 139   Game Date   Game Time  Matchup                    Team
# 140         NaN         NaN      NaN                     NaN
# 141         NaN         NaN      NaN                     NaN
# 142         NaN         NaN      NaN                     NaN
# 143         NaN         NaN      NaN                     NaN
# 144         NaN         NaN      NaN                     NaN
# 145         NaN         NaN      NaN                     NaN
# 146         NaN         NaN      NaN    New Orleans Pelicans
# 147         NaN         NaN      NaN                     NaN
# 148         NaN         NaN      NaN                     NaN
# 149         NaN         NaN      NaN                     NaN
# 150         NaN         NaN      NaN                     NaN
# 151         NaN         NaN      NaN                     NaN
# 152         NaN         NaN      NaN                     NaN
# 153         NaN         NaN  MIL@CHI           Chicago Bulls
# 154         NaN         NaN      NaN                     NaN
# 155         NaN         NaN      NaN                     NaN
# 156         NaN         NaN      NaN                     NaN
# 157         NaN         NaN      NaN                     NaN
# 158         NaN         NaN      NaN         Milwaukee Bucks
# 159         NaN         NaN  UTA@SAC        Sacramento Kings
# 160         NaN         NaN      NaN                     NaN
# 161         NaN         NaN      NaN                     NaN
# 162         NaN         NaN      NaN                     NaN
# 163         NaN         NaN      NaN                     NaN
# 164         NaN         NaN      NaN                     NaN
# 165         NaN         NaN      NaN                     NaN
# 166         NaN         NaN      NaN               Utah Jazz
#
#                   Player Name  Current Status  \
# 0               Brown, Jaylen             Out
# 1              Fournier, Evan             Out
# 2               Smart, Marcus             Out
# 3               Tatum, Jayson             Out
# 4           Thompson, Tristan             Out
# 5               Walker, Kemba             Out
# 6        Williams III, Robert             Out
# 7          Robinson, Mitchell             Out
# 8               Vildoza, Luca             Out
# 9             Hayward, Gordon             Out
# 10               Martin, Cody             Out
# 11               Avdija, Deni             Out
# 12              Beal, Bradley       Available
# 13             Bryant, Thomas             Out
# 14          Mathews, Garrison       Available
# 15                 Neto, Raul             Out
# 16           Brogdon, Malcolm             Out
# 17             Holiday, Aaron             Out
# 18               Lamb, Jeremy             Out
# 19          Sabonis, Domantas       Available
# 20             Sumner, Edmond             Out
# 21              Turner, Myles             Out
# 22               Warren, T.J.             Out
# 23                Anunoby, OG             Out
# 24              Harris, Jalen             Out
# 25               Hood, Rodney             Out
# 26                Lowry, Kyle             Out
# 27                Player Name  Current Status
# 28             Siakam, Pascal             Out
# 29             VanVleet, Fred             Out
# 30             Watanabe, Yuta             Out
# 31               Watson, Paul             Out
# 32             Ayton, Deandre             Out
# 33              Booker, Devin             Out
# 34               Crowder, Jae             Out
# 35           Johnson, Cameron             Out
# 36               Nader, Abdel             Out
# 37                Paul, Chris             Out
# 38                  Gay, Rudy       Available
# 39           Jeffries, DaQuan             Out
# 40                Lyles, Trey             Out
# 41               Mills, Patty             Out
# 42           Murray, Dejounte       Available
# 43              Samanic, Luka             Out
# 44          Walker IV, Lonnie       Available
# 45             White, Derrick             Out
# 46                Lee, Damion             Out
# 47           Oubre Jr., Kelly             Out
# 48             Thompson, Klay             Out
# 49             Wiseman, James             Out
# 50             Allen, Grayson             Out
# 51            McDermott, Sean             Out
# 52               Brown, Bruce       Available
# 53             Chiozza, Chris             Out
# 54         Dinwiddie, Spencer             Out
# 55                Player Name  Current Status
# 56              Harden, James             Out
# 57                Harris, Joe             Out
# 58       Dellavedova, Matthew             Out
# 59            Garland, Darius             Out
# 60        Hartenstein, Isaiah             Out
# 61                Love, Kevin             Out
# 62           Nance Jr., Larry             Out
# 63            Prince, Taurean             Out
# 64             Stevens, Lamar             Out
# 65             Windler, Dylan             Out
# 66         Bogdanovic, Bogdan             Out
# 67              Capela, Clint             Out
# 68                 Dunn, Kris             Out
# 69          Gallinari, Danilo             Out
# 70           Goodwin, Brandon             Out
# 71             Huerter, Kevin             Out
# 72            Okongwu, Onyeka       Available
# 73               Reddish, Cam             Out
# 74                Snell, Tony       Available
# 75                Young, Trae       Available
# 76             Bradley, Avery             Out
# 77            Brown, Sterling             Out
# 78                Exum, Dante             Out
# 79               Gordon, Eric             Out
# 80          House Jr., Danuel             Out
# 81               Nwaba, David             Out
# 82          Porter Jr., Kevin             Out
# 83                Player Name  Current Status
# 84              Thomas, Khyri             Out
# 85                 Wall, John             Out
# 86            Wood, Christian             Out
# 87                  Bamba, Mo       Available
# 88        Carter Jr., Wendell             Out
# 89   Carter-Williams, Michael             Out
# 90           Ennis III, James             Out
# 91            Fultz, Markelle             Out
# 92              Hampton, R.J.       Available
# 93            Isaac, Jonathan             Out
# 94               Okeke, Chuma             Out
# 95           Porter Jr., Otto             Out
# 96             Ross, Terrence             Out
# 97                Curry, Seth             Out
# 98               Embiid, Joel             Out
# 99               Green, Danny             Out
# 100            Harris, Tobias             Out
# 101           Korkmaz, Furkan       Available
# 102             Milton, Shake       Available
# 103              Simmons, Ben             Out
# 104         Thybulle, Matisse             Out
# 105          Doumbouya, Sekou             Out
# 106          Ellington, Wayne             Out
# 107             Grant, Jerami             Out
# 108            Jackson, Frank             Out
# 109              Joseph, Cory       Available
# 110          McGruder, Rodney             Out
# 111               Player Name  Current Status
# 112        Sirvydis, Deividas             Out
# 113         Smith Jr., Dennis             Out
# 114           Stewart, Isaiah             Out
# 115              Adebayo, Bam             Out
# 116             Ariza, Trevor             Out
# 117             Butler, Jimmy             Out
# 118             Dragic, Goran             Out
# 119           Iguodala, Andre             Out
# 120            Nunn, Kendrick             Out
# 121           Oladipo, Victor             Out
# 122           Yurtseven, Omer             Out
# 123              Kleber, Maxi             Out
# 124                Redick, JJ             Out
# 125            Beasley, Malik             Out
# 126           Culver, Jarrett             Out
# 127              Barton, Will             Out
# 128                Dozier, PJ             Out
# 129             Murray, Jamal             Out
# 130             Collins, Zach             Out
# 131              Coffey, Amir             Out
# 132         Cousins, DeMarcus             Out
# 133             Mann, Terance       Available
# 134            Dort, Luguentz             Out
# 135  Gilgeous-Alexander, Shai             Out
# 136                Jerome, Ty       Available
# 137             Muscala, Mike             Out
# 138              Caruso, Alex       Available
# 139               Player Name  Current Status
# 140            Davis, Anthony       Available
# 141             Dudley, Jared       Available
# 142               Gasol, Marc       Available
# 143             James, LeBron       Available
# 144               Kuzma, Kyle       Available
# 145         McKinnie, Alfonzo       Available
# 146             Adams, Steven             Out
# 147               Ball, Lonzo             Out
# 148                Hart, Josh             Out
# 149           Ingram, Brandon             Out
# 150               Iwundu, Wes             Out
# 151            Johnson, James       Available
# 152          Williamson, Zion             Out
# 153           Brown Jr., Troy             Out
# 154              LaVine, Zach             Out
# 155         Satoransky, Tomas             Out
# 156             Theis, Daniel             Out
# 157           Vucevic, Nikola             Out
# 158          Middleton, Khris             Out
# 159        Bagley III, Marvin        Doubtful
# 160          Barnes, Harrison        Doubtful
# 161             Fox, De'Aaron             Out
# 162        Haliburton, Tyrese             Out
# 163           Holmes, Richaun             Out
# 164             James, Justin             Out
# 165         Whiteside, Hassan    Questionable
# 166         Mitchell, Donovan             Out
#
#                                                 Reason
# 0    Injury/Illness - Left Scapholunate; Ligament S...
# 1            Injury/Illness - Right Knee; Hyperflexion
# 2               Injury/Illness - Right Calf; Contusion
# 3             Injury/Illness - Left Ankle; Impingement
# 4               Injury/Illness - Left Pectoral; Strain
# 5     Injury/Illness - Left Cervical Nerve; Irritation
# 6                 Injury/Illness - Left Foot; Turf Toe
# 7                 Injury/Illness - Right Foot; surgery
# 8                                        Not With Team
# 9                  Injury/Illness - Right Foot; Sprain
# 10                 Injury/Illness - Left Ankle; Sprain
# 11   Injury/Illness - Right Ankle; Right ankle frac...
# 12   Injury/Illness - Left Hamstring; Left hamstrin...
# 13         Injury/Illness - Left Knee; Left ACL injury
# 14    Injury/Illness - Right Wrist; Right wrist sprain
# 15   Injury/Illness - Left Hamstring; Left hamstrin...
# 16              Injury/Illness - Right Hamstring; Sore
# 17        Injury/Illness - Right Toe; Great Toe Sprain
# 18                    Injury/Illness - Left Knee; Sore
# 19                 Injury/Illness - Left Quad; Bruised
# 20               Injury/Illness - Left Knee; Contusion
# 21   Injury/Illness - Right Toe; Partial Plantar Pl...
# 22         Injury/Illness - Left Foot; Stress Fracture
# 23   Injury/Illness - Left Calf; Strain - injury re...
# 24                Injury/Illness - Left Foot; Soreness
# 25   Injury/Illness - Left Hand; Fracture - second ...
# 26                                                Rest
# 27                                              Reason
# 28              Injury/Illness - Left Shoulder; Strain
# 29   Injury/Illness - Left Hip; Flexor- injury reco...
# 30              Injury/Illness - Right Ankle; Soreness
# 31              Injury/Illness - Left Knee; Tendinitis
# 32                Injury/Illness - Left Knee; Soreness
# 33                                                Rest
# 34     Injury/Illness - Right Ankle; Injury Management
# 35                Injury/Illness - Right Wrist; Sprain
# 36            Injury/Illness - Right Knee; Arthroscopy
# 37                                                Rest
# 38               Injury/Illness - Right Heel; Soreness
# 39                                       Not With Team
# 40                Injury/Illness - Right Ankle; Sprain
# 41                                                Rest
# 42     Injury/Illness - Bilateral Lower Back; Soreness
# 43   Injury/Illness - Left Fourth Metacarpal; Fracture
# 44          Injury/Illness - Left Quadriceps; Soreness
# 45                Injury/Illness - Right Ankle; Sprain
# 46                         Health and Safety Protocols
# 47               Injury/Illness - Left Wrist; Soreness
# 48      Injury/Illness - Right Achilles Tendon; Repair
# 49          Injury/Illness - Right Knee; Meniscus Tear
# 50           Injury/Illness - Left Abdominal; Soreness
# 51                Injury/Illness - Left Foot; Soreness
# 52                    Injury/Illness - Nasal; Fracture
# 53   Injury/Illness - Right Hand; Fractured Third M...
# 54     Injury/Illness - Right Knee; Partially Torn ACL
# 55                                              Reason
# 56   Injury/Illness - Right Hamstring; Injury Manag...
# 57               Injury/Illness - Left Gluteal; Strain
# 58                       Injury/Illness - Neck; Strain
# 59   Injury/Illness - Left Ankle; Sprain - Injury M...
# 60                   Injury/Illness - Head; Concussion
# 61   Injury/Illness - Right Calf; Strain - Injury M...
# 62              Injury/Illness - Right Thumb; Fracture
# 63                Injury/Illness - Left Ankle; Surgery
# 64                   Injury/Illness - Head; Concussion
# 65                 Injury/Illness - Left Knee; Surgery
# 66           Injury/Illness - Left Hamstring; Soreness
# 67            Injury/Illness - Left Achilles; Soreness
# 68            Injury/Illness - Left Ankle; Impingement
# 69                 Injury/Illness - Low Back; Soreness
# 70                 Injury/Illness - Flu-like; Symptoms
# 71               Injury/Illness - Left Ankle; Soreness
# 72           Injury/Illness - Right Shoulder; Soreness
# 73           Injury/Illness - Right Achilles; Soreness
# 74           Injury/Illness - Right Achilles; Soreness
# 75            Injury/Illness - Right Big Toe; Soreness
# 76                                    Personal Reasons
# 77             Injury/Illness - Head/face; Lacerations
# 78                 Injury/Illness - Right Calf; Strain
# 79                Injury/Illness - Right Groin; Strain
# 80              Injury/Illness - Right Ankle; Soreness
# 81                Injury/Illness - Right Wrist; Sprain
# 82                 Injury/Illness - Left Ankle; Sprain
# 83                                              Reason
# 84           Injury/Illness - Right Achilles; Soreness
# 85            Injury/Illness - Right Hamstring; Strain
# 86              Injury/Illness - Right Ankle; Soreness
# 87           Injury/Illness - N/A; Illness (non Covid)
# 88                 Injury/Illness - Left Eye; Abrasion
# 89                 Injury/Illness - Left Ankle; Sprain
# 90                   Injury/Illness - Right Calf; Sore
# 91                Injury/Illness - Left Knee; Torn ACL
# 92                Injury/Illness - Right Ankle; Sprain
# 93          Injury/Illness - Left Knee; Injury Recover
# 94                 Injury/Illness - Left Ankle; Sprain
# 95                    Injury/Illness - Left Foot; Pain
# 96                       Injury/Illness - Back; Spasms
# 97         Injury/Illness - Right Hip; Injury Recovery
# 98             Injury/Illness - N/a; Non COVID Illness
# 99          Injury/Illness - Left Hip; Injury Recovery
# 100       Injury/Illness - Right Knee; Injury recovery
# 101               Injury/Illness - Right Ankle; Sprain
# 102              Injury/Illness - Right Knee; Soreness
# 103                   Injury/Illness - Back; Stiffness
# 104               Injury/Illness - Left Hand; Swelling
# 105                                   Personal Reasons
# 106            Injury/Illness - Bilateral Calf; Strain
# 107              Injury/Illness - Right Knee; Soreness
# 108               Injury/Illness - Right Ankle; Sprain
# 109              Injury/Illness - Left Ankle; Soreness
# 110               Injury/Illness - Right Elbow; Sprain
# 111                                             Reason
# 112             Injury/Illness - Left Tibia; Contusion
# 113               Injury/Illness - Left Knee; Soreness
# 114                                   Personal Reasons
# 115                                               Rest
# 116                                               Rest
# 117             Injury/Illness - Lower Back; tightness
# 118  Injury/Illness - Lower Back; R Knee - injury r...
# 119         Injury/Illness - Left hip; Injury Recovery
# 120        Injury/Illness - Left Calf; Injury Recovery
# 121               Injury/Illness - Right Knee; Surgery
# 122                                      Not With Team
# 123          Injury/Illness - Right Achilles; Soreness
# 124              Injury/Illness - Right Heel; Soreness
# 125            Injury/Illness - Left Hamstring; Injury
# 126              Injury/Illness - Right Ankle; Surgery
# 127           Injury/Illness - Right Hamstring; Strain
# 128            Injury/Illness - Right Adductor; Strain
# 129                 Injury/Illness - Left Acl; Surgery
# 130       Injury/Illness - Left Ankle; Stress Fracture
# 131                        Health and Safety Protocols
# 132               Injury/Illness - Left Foot; Soreness
# 133                                   Personal Reasons
# 134   Injury/Illness - Right Knee; Patellar Tendinitis
# 135     Injury/Illness - Right Foot; Plantar Fasciitis
# 136                 Injury/Illness - Left Calf; Strain
# 137               Injury/Illness - Right Ankle; Sprain
# 138              Injury/Illness - Right Foot; Soreness
# 139                                             Reason
# 140          Injury/Illness - Left Adductor; Tightness
# 141                   Injury/Illness - Right MCL; Tear
# 142  Injury/Illness - Left Pinkie Finger; Volar Pla...
# 143               Injury/Illness - Right Ankle; Sprain
# 144             Injury/Illness - Lower Back; Tightness
# 145                Injury/Illness - Right Foot; Sprain
# 146           Injury/Illness - Right First MTP; Sprain
# 147               Injury/Illness - Right Thumb; Strain
# 148              Injury/Illness - Right Thumb; Surgery
# 149                Injury/Illness - Left Ankle; Sprain
# 150             Injury/Illness - Left Shoulder; Sprain
# 151              Injury/Illness - Left Knee; Contusion
# 152               Injury/Illness - Left Hand; Fracture
# 153                Injury/Illness - Left Ankle; Sprain
# 154   Injury/Illness - Right Knee; Patellar Tendinitis
# 155                Injury/Illness - Left Ankle; Sprain
# 156                 Injury/Illness - Right Hip; Sprain
# 157                                               Rest
# 158              Injury/Illness - Left Ankle; Soreness
# 159            Injury/Illness - Right Groin; Tightness
# 160          Injury/Illness - Left Adductor; Tightness
# 161                        Health and Safety Protocols
# 162         Injury/Illness - Left Knee; Hyperextension
# 163              Injury/Illness - Right Knee; Soreness
# 164               Injury/Illness - Right Ankle; Sprain
# 165               Injury/Illness - Low Back; Tightness
# 166               Injury/Illness - Right Ankle; Sprain

# %%
dfs = list()
for pdf in tqdm(pdfs):
    print(f'processing {pdf}')
    df = tabula.read_pdf(pdf, stream=True, area=[52.099,16.84,562.561,834.632], pages='all')
    df = clean_injury_report(df)
    dfs.append(df)
# Out:
#   0%|          | 0/124 [00:00<?, ?it/s]
# processing 2021-03-14_08PM.pdf
# processing 2021-03-15_08PM.pdf
# processing 2021-03-16_08PM.pdf
# processing 2021-03-17_08PM.pdf
# processing 2021-03-18_08PM.pdf
# processing 2021-03-19_08PM.pdf
# processing 2021-03-20_08PM.pdf
# processing 2021-03-21_08PM.pdf
# processing 2021-03-22_08PM.pdf
# processing 2021-03-23_08PM.pdf
# processing 2021-03-24_08PM.pdf
# processing 2021-03-25_08PM.pdf
# processing 2021-03-26_08PM.pdf
# processing 2021-03-27_08PM.pdf
# processing 2021-03-28_08PM.pdf
# processing 2021-03-29_08PM.pdf
# processing 2021-03-30_08PM.pdf
# processing 2021-03-31_08PM.pdf
# processing 2021-04-01_08PM.pdf
# processing 2021-04-02_08PM.pdf
# processing 2021-04-03_08PM.pdf
# processing 2021-04-04_08PM.pdf
# processing 2021-04-05_08PM.pdf
# processing 2021-04-06_08PM.pdf
# processing 2021-04-07_08PM.pdf
# processing 2021-04-08_08PM.pdf
# processing 2021-04-09_08PM.pdf
# processing 2021-04-10_08PM.pdf
# processing 2021-04-11_08PM.pdf
# processing 2021-04-12_08PM.pdf
# processing 2021-04-13_08PM.pdf
# processing 2021-04-14_08PM.pdf
# processing 2021-04-15_08PM.pdf
# processing 2021-04-16_08PM.pdf
# processing 2021-04-17_08PM.pdf
# processing 2021-04-18_08PM.pdf
# processing 2021-04-19_08PM.pdf
# processing 2021-04-20_08PM.pdf
# processing 2021-04-21_08PM.pdf
# processing 2021-04-22_08PM.pdf
# processing 2021-04-23_08PM.pdf
# processing 2021-04-24_08PM.pdf
# processing 2021-04-25_08PM.pdf
# processing 2021-04-26_08PM.pdf
# processing 2021-04-27_08PM.pdf
# processing 2021-04-28_08PM.pdf
# processing 2021-04-29_08PM.pdf
# processing 2021-04-30_08PM.pdf
# processing 2021-05-01_08PM.pdf
# processing 2021-05-02_08PM.pdf
# processing 2021-05-03_08PM.pdf
# processing 2021-05-04_08PM.pdf
# processing 2021-05-05_08PM.pdf
# processing 2021-05-06_08PM.pdf
# processing 2021-05-07_08PM.pdf
# processing 2021-05-08_08PM.pdf
# processing 2021-05-09_08PM.pdf
# processing 2021-05-10_08PM.pdf
# processing 2021-05-11_08PM.pdf
# processing 2021-05-12_08PM.pdf
# processing 2021-05-13_08PM.pdf
# processing 2021-05-14_08PM.pdf
# processing 2021-05-15_08PM.pdf
# processing 2021-05-16_08PM.pdf
# processing 2021-05-17_08PM.pdf
# processing 2021-05-18_08PM.pdf
# processing 2021-05-19_08PM.pdf
# processing 2021-05-20_08PM.pdf
# processing 2021-05-21_08PM.pdf
# processing 2021-05-22_08PM.pdf
# processing 2021-05-23_08PM.pdf
# processing 2021-05-24_08PM.pdf
# processing 2021-05-25_08PM.pdf
# processing 2021-05-26_08PM.pdf
# processing 2021-05-27_08PM.pdf
# processing 2021-05-28_08PM.pdf
# processing 2021-05-29_08PM.pdf
# processing 2021-05-30_08PM.pdf
# processing 2021-05-31_08PM.pdf
# processing 2021-06-01_08PM.pdf
# processing 2021-06-02_08PM.pdf
# processing 2021-06-03_08PM.pdf
# processing 2021-06-04_08PM.pdf
# processing 2021-06-05_08PM.pdf
# processing 2021-06-06_08PM.pdf
# processing 2021-06-07_08PM.pdf
# processing 2021-06-08_08PM.pdf
# processing 2021-06-09_08PM.pdf
# processing 2021-06-10_08PM.pdf
# processing 2021-06-11_08PM.pdf
# processing 2021-06-12_08PM.pdf
# processing 2021-06-13_08PM.pdf
# processing 2021-06-14_08PM.pdf
# processing 2021-06-15_08PM.pdf
# processing 2021-06-16_08PM.pdf
# processing 2021-06-17_08PM.pdf
# processing 2021-06-18_08PM.pdf
# processing 2021-06-19_08PM.pdf
# processing 2021-06-20_08PM.pdf
# processing 2021-06-21_08PM.pdf
# processing 2021-06-22_08PM.pdf
# processing 2021-06-23_08PM.pdf
# processing 2021-06-24_08PM.pdf
# processing 2021-06-25_08PM.pdf
# processing 2021-06-26_08PM.pdf
# processing 2021-06-27_08PM.pdf
# processing 2021-06-28_08PM.pdf
# processing 2021-06-29_08PM.pdf
# processing 2021-06-30_08PM.pdf
# processing 2021-07-01_08PM.pdf
# processing 2021-07-02_08PM.pdf
# processing 2021-07-03_08PM.pdf
# processing 2021-07-05_08PM.pdf
# processing 2021-07-06_08PM.pdf
# processing 2021-07-07_08PM.pdf
# processing 2021-07-08_08PM.pdf
# processing 2021-07-10_08PM.pdf
# processing 2021-07-11_08PM.pdf
# processing 2021-07-13_08PM.pdf
# processing 2021-07-14_08PM.pdf
# processing 2021-07-16_08PM.pdf
# processing 2021-07-17_08PM.pdf
# processing 2021-07-19_08PM.pdf
# processing 2021-07-20_08PM.pdf

# %%
df = pd.concat(dfs)

# %%
df
# Out:
#      Game Date   Game Time  Matchup                   Team  \
# 0   03/14/2021  02:00 (ET)  MEM@OKC      Memphis Grizzlies
# 1   03/14/2021  02:00 (ET)  MEM@OKC  Oklahoma City Thunder
# 2   03/14/2021  02:00 (ET)  MEM@OKC  Oklahoma City Thunder
# 3   03/14/2021  02:00 (ET)  MEM@OKC  Oklahoma City Thunder
# 4   03/14/2021  02:00 (ET)  MEM@OKC  Oklahoma City Thunder
# ..         ...         ...      ...                    ...
# 1   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 2   07/20/2021  09:00 (ET)  PHX@MIL           Phoenix Suns
# 0   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 1   07/20/2021  09:00 (ET)  PHX@MIL        Milwaukee Bucks
# 2   07/20/2021  09:00 (ET)  PHX@MIL           Phoenix Suns
#
#                 Player Name Current Status  \
# 0        Jackson Jr., Jaren            Out
# 1             Ariza, Trevor            Out
# 2            Bazley, Darius            Out
# 3            Dort, Luguentz            Out
# 4                Hall, Josh            Out
# ..                      ...            ...
# 1         DiVincenzo, Donte            Out
# 2              Saric, Dario            Out
# 0   Antetokounmpo, Thanasis            Out
# 1         DiVincenzo, Donte            Out
# 2              Saric, Dario            Out
#
#                                                Reason
# 0   Injury/Illness - Left Knee; Meniscus Surgery R...
# 1                                       Not With Team
# 2           Injury/Illness - Left Shoulder; Contusion
# 3             Injury/Illness - Left Great Toe; Sprain
# 4                Injury/Illness - Left Knee; Soreness
# ..                                                ...
# 1                Injury/Illness - Left Ankle; Surgery
# 2                    Injury/Illness - Right Acl; Tear
# 0                         Health and Safety Protocols
# 1                Injury/Illness - Left Ankle; Surgery
# 2                    Injury/Illness - Right Acl; Tear
#
# [7924 rows x 7 columns]

# %%
df['Game Date'].nunique()
# Out:
# 115

# %%
len(season_dates)
# Out:
# 207

# %% [markdown]
# {{ "If you happen to find a central place for these, let me know!" | fndetail: 1 }}

# %% [markdown]
# {{ "I'm going to try my best to show the provenance of as much insight as I can here.  I had no idea when the injury reports came out, so I googled it.  Don't be ashamed to do likewise if there's something you need to know!" | fndetail: 2 }}

# %% [markdown]
# {{ '...and sincerely apologize to Adam Silver next time we run into him for the extra traffic on the [nba.com](https://nba.com) servers.' | fndetail: 3 }}

# %% [markdown]
# {{ 'Ideally we would *[generate](https://www.geeksforgeeks.org/python-list-comprehensions-vs-generator-expressions/)* the list versus building it all at once, but conceptually it&#39;s the same thing' | fndetail: 4 }}

# %% [markdown]
# {{ "From manual inspection of the HTTP headers, it looks like nba.com returns a 403 ('Forbidden') when there isn't a valid PDF" | fndetail: 5 }}

# %% [markdown]
# {{ "If you're thinking 'You should do both', you get a gold star!" | fndetail: 6 }}

# %% [markdown]
# ## Footnotes
#
# You can have footnotes in notebooks, however the syntax is different compared to markdown documents. [This guide provides more detail about this syntax](https://github.com/fastai/fastpages/blob/master/_fastpages_docs/NOTEBOOK_FOOTNOTES.md), which looks like this:
#
# ```
# {% raw %}For example, here is a footnote {% fn 1 %}.
# And another {% fn 2 %}
# {{ 'This is the footnote.' | fndetail: 1 }}
# {{ 'This is the other footnote. You can even have a [link](www.github.com)!' | fndetail: 2 }}{% endraw %}
# ```
#
# For example, here is a footnote {% fn 10 %}.
#
# And another {% fn 11 %}
#
# {{ 'This is the footnote.' | fndetail: 10 }}
# {{ 'This is the other footnote. You can even have a [link](www.github.com)!' | fndetail: 11 }}
